# %% [markdown]
# # 2024-01-20 20 - Train-based constraint level estimation.ipynb
# Copy of NB 13, calculate constraints based on training MSE on ERM runs for January's batch of experiments.

# %% [markdown]
# ## Fetching runs

# %%
import wandb
from math import isnan 
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import wandb
from tqdm import tqdm
# from cycler import cycler
import matplotlib as mpl
from IPython.display import Markdown, display
    
api = wandb.Api()
project = "Autoformer"
workspace = "alelab"

experiment_tags = [
    "e11_erm_weather_dlfix",
    "e12_erm_electricity_dlfix",
    "e13_erm_exchange_dlfix",
    ]

# get all runs that both: 1.  match any experiment tag and 2. are finished
runs = api.runs(f"{workspace}/{project}",
                {"$and": [
                    {"tags": {"$in": experiment_tags}},
                    # Get only ERM runs: {"config.dual_lr": 0},
                    {"config.dual_lr": 0},
                    {"state": "finished"}
                ]})

def tag_experiment(run):
    for tag in experiment_tags:
        if tag in run.tags:
            return tag
    return ''

def runs_into_df(runs):
    all_runs = []
    run_counter = 0
    for run in tqdm(runs):
        run_counter += 1
        for split in ["train", "test","val"]:
            for metric in ["mse",]:
                pred_len = run.config["pred_len"]
                metrics = np.zeros(pred_len)
                for i in range(pred_len):
                    run_dict = {**run.config}
                    #run_dict["constraint_level"] = constraint_level
                    run_dict[f"{metric}"] = run.summary[f"{metric}/{split}/{i}"]
                    #run_dict[f"{metric}"] = run.summary.get(f"{metric}/{split}/{i}",run.summary.get(f"mse/{split}/{i}",np.nan)) #god forgive me for this line
                    run_dict["step"]=i
                    run_dict["epoch"]=run.summary["epoch"]
                    run_dict["infeasible_rate"]=run.summary[f"infeasible_rate/{split}"]
                    run_dict["infeasibles"]=run.summary[f"infeasibles/{split}"]
                    run_dict[f"multiplier"] = run.summary[f"multiplier/{i}"] if split == "train" else np.nan
                    run_dict["split"] = split
                    run_dict["run_id"] = run.id
                    # Get either Constrained/ or ERM/ from the run name, then append model name.
                    #print("run.name", run.name)
                    #debug if ERM run
                    run_dict["Algorithm"] = f"{run.name.split('/')[0]} {run.config['model']}"
                    run_dict["sweep_id"] = run.sweep.id if run.sweep else ''
                    #print("Algorithm", run_dict["Algorithm"])

                    # Get the experiment tag
                    run_dict["experiment_tag"] = tag_experiment(run)

                    # To better plot constrained vs ERM
                    #TODO this is a hack while I consolidate the tags. 
                    run_dict["type"] = "ERM" if run.config['dual_lr'] == 0 else "Constrained"

                    all_runs.append(run_dict)
    print(f"Fetched {run_counter} runs")
    df = pd.DataFrame(all_runs)
    print(f"Total records: {(df.shape)}")
    print(f"Total runs: {df.run_id.nunique()}")
    return df
df = runs_into_df(runs)
# Out:
# 100%|██████████| 120/120 [00:10<00:00, 11.86it/s]
# Fetched 120 runs
# Total records: (120960, 76)
# Total runs: 120

# %%
df[['run_id',"sweep_id",'Algorithm',"type",'model','data_path','constraint_level','pred_len']].drop_duplicates().sort_values(['model',"pred_len","constraint_level"])
# Out:
#           run_id  sweep_id                                    Algorithm type  \
# 23616   yl4lsmf1  7z00icod      Weather-StatInformed-ERM-10e Autoformer  ERM
# 23904   txo8m3o0  j115hcxz      Weather-StatInformed-ERM-10e Autoformer  ERM
# 36000   9sqnju3c  ro3nwbin     Exchange-StatInformed-ERM-10e Autoformer  ERM
# 48096   m0dkle2c  jsh6vre8  Electricity-StatInformed-ERM-10e Autoformer  ERM
# 60192   uchtvkhp  kqk88y4g      Weather-StatInformed-ERM-10e Autoformer  ERM
# ...          ...       ...                                          ...  ...
# 64512   srxqrvth  pzuksd9e       Exchange-StatInformed-ERM-10e Reformer  ERM
# 76608   k1woe3lg  2fvhx9ou    Electricity-StatInformed-ERM-10e Reformer  ERM
# 88704   014gnz8z  80y93xe0        Weather-StatInformed-ERM-10e Reformer  ERM
# 100800  g02aylnp  8xqpivas       Exchange-StatInformed-ERM-10e Reformer  ERM
# 112896  jvd22qd3  xzs2oeju    Electricity-StatInformed-ERM-10e Reformer  ERM
#
#              model          data_path  constraint_level  pred_len
# 23616   Autoformer        weather.csv                -1        96
# 23904   Autoformer        weather.csv                -1        96
# 36000   Autoformer  exchange_rate.csv                -1        96
# 48096   Autoformer    electricity.csv                -1        96
# 60192   Autoformer        weather.csv                -1        96
# ...            ...                ...               ...       ...
# 64512     Reformer  exchange_rate.csv                -1       720
# 76608     Reformer    electricity.csv                -1       720
# 88704     Reformer        weather.csv                -1       720
# 100800    Reformer  exchange_rate.csv                -1       720
# 112896    Reformer    electricity.csv                -1       720
#
# [120 rows x 8 columns]

# %% [markdown]
# # Get IQR for all models, and pred lengths, datasets
# Note that the IQRs are vastly different for autoformer and reformer.

# %%
stats=df.query("split=='train'").groupby(['data_path','model','pred_len'])['mse'].describe().reset_index()
constraint_data=stats[['data_path','model','pred_len','25%','50%','75%','mean','std']].sort_values(['data_path','pred_len','model'])
constraint_data
# Out:
#             data_path       model  pred_len       25%       50%       75%  \
# 0     electricity.csv  Autoformer        96  0.127740  0.130797  0.137069
# 4     electricity.csv    Informer        96  0.170214  0.174671  0.182912
# 8     electricity.csv    Reformer        96  0.174376  0.176341  0.178398
# 1     electricity.csv  Autoformer       192  0.158004  0.163558  0.171457
# 5     electricity.csv    Informer       192  0.188372  0.192644  0.197674
# 9     electricity.csv    Reformer       192  0.184147  0.185285  0.186903
# 2     electricity.csv  Autoformer       336  0.168818  0.178750  0.188562
# 6     electricity.csv    Informer       336  0.219842  0.224648  0.232744
# 10    electricity.csv    Reformer       336  0.193268  0.193908  0.194859
# 3     electricity.csv  Autoformer       720  0.201388  0.209942  0.223790
# 7     electricity.csv    Informer       720  0.340948  0.372836  0.426282
# 11    electricity.csv    Reformer       720  0.201543  0.205141  0.206657
# 12  exchange_rate.csv  Autoformer        96  0.119256  0.174272  0.241762
# 16  exchange_rate.csv    Informer        96  0.052321  0.055573  0.058596
# 20  exchange_rate.csv    Reformer        96  0.095706  0.136493  0.175075
# 13  exchange_rate.csv  Autoformer       192  0.219767  0.291897  0.377080
# 17  exchange_rate.csv    Informer       192  0.055175  0.057496  0.061581
# 21  exchange_rate.csv    Reformer       192  0.156502  0.237633  0.310000
# 14  exchange_rate.csv  Autoformer       336  0.278680  0.395856  0.548553
# 18  exchange_rate.csv    Informer       336  0.060993  0.064795  0.069034
# 22  exchange_rate.csv    Reformer       336  0.235601  0.370420  0.484407
# 15  exchange_rate.csv  Autoformer       720  0.417548  0.845012  1.153175
# 19  exchange_rate.csv    Informer       720  0.067816  0.071834  0.079026
# 23  exchange_rate.csv    Reformer       720  0.370338  0.592544  0.682842
# 24        weather.csv  Autoformer        96  0.349652  0.371932  0.401564
# 28        weather.csv    Informer        96  0.238400  0.245110  0.251286
# 32        weather.csv    Reformer        96  0.314408  0.342177  0.361925
# 25        weather.csv  Autoformer       192  0.396631  0.475671  0.662901
# 29        weather.csv    Informer       192  0.251661  0.257634  0.266199
# 33        weather.csv    Reformer       192  0.346080  0.366626  0.387131
# 26        weather.csv  Autoformer       336  0.502725  0.564399  0.674186
# 30        weather.csv    Informer       336  0.263343  0.270707  0.279756
# 34        weather.csv    Reformer       336  0.365656  0.381001  0.394330
# 27        weather.csv  Autoformer       720  0.685310  0.747550  0.776649
# 31        weather.csv    Informer       720  0.284203  0.289314  0.302384
# 35        weather.csv    Reformer       720  0.364128  0.368968  0.373198
#
#         mean       std
# 0   0.135374  0.013636
# 4   0.177596  0.009735
# 8   0.176810  0.003726
# 1   0.168043  0.017472
# 5   0.193602  0.007632
# 9   0.185970  0.003507
# 2   0.180856  0.018951
# 6   0.227809  0.011531
# 10  0.194635  0.004194
# 3   0.216470  0.026430
# 7   0.408939  0.105977
# 11  0.204905  0.005983
# 12  0.185632  0.070246
# 16  0.055617  0.004740
# 20  0.134437  0.044151
# 13  0.297360  0.110412
# 17  0.059070  0.005518
# 21  0.233079  0.081282
# 14  0.413427  0.171521
# 18  0.065943  0.006639
# 22  0.359700  0.129615
# 15  0.810366  0.416756
# 19  0.074540  0.010428
# 23  0.538167  0.185741
# 24  0.378128  0.043202
# 28  0.244628  0.013207
# 32  0.333128  0.039386
# 25  0.529925  0.146895
# 29  0.258276  0.012927
# 33  0.361673  0.032793
# 26  0.577774  0.117853
# 30  0.271325  0.012563
# 34  0.377275  0.024109
# 27  0.701729  0.126207
# 31  0.293587  0.015400
# 35  0.367956  0.008233

# %% [markdown]
# # Parsing constraints to paste on sweeps

# %%
import yaml

# Iterate over each row in the DataFrame
for index, row in constraint_data.iterrows():
    # Extract the necessary values
    model_name = row['model']
    data_path = row['data_path']
    pred_len = row['pred_len']
    constraint_level_values = row[['25%', '50%', '75%']].astype(float).values.round(3)

    # Create the configuration dictionary
    config = {
        'model': {'value': f'{model_name}'},
        'constraint_level': {'values': constraint_level_values.tolist()}
    }

    # Generate the comment
    comment = f"# {data_path}, pred_len={pred_len}, {model_name}"

    # Convert the dictionary to a YAML string
    yaml_config = yaml.dump(config, default_flow_style=False)

    # Replace the list representation with an array representation
    yaml_config = yaml_config.replace('values:\n  - ', 'values: [')
    yaml_config = yaml_config.replace('\n  - ', ', ')

    # Add the closing bracket for the array
    yaml_config = yaml_config.replace('\nmodel', ']\nmodel')

    # Combine the comment and the YAML string
    yaml_output = comment + '\n' + yaml_config

    print(yaml_output)
# Out:
# # electricity.csv, pred_len=96, Autoformer
# constraint_level:
#   values: [0.128, 0.131, 0.137]
# model:
#   value: Autoformer
#
# # electricity.csv, pred_len=96, Informer
# constraint_level:
#   values: [0.17, 0.175, 0.183]
# model:
#   value: Informer
#
# # electricity.csv, pred_len=96, Reformer
# constraint_level:
#   values: [0.174, 0.176, 0.178]
# model:
#   value: Reformer
#
# # electricity.csv, pred_len=192, Autoformer
# constraint_level:
#   values: [0.158, 0.164, 0.171]
# model:
#   value: Autoformer
#
# # electricity.csv, pred_len=192, Informer
# constraint_level:
#   values: [0.188, 0.193, 0.198]
# model:
#   value: Informer
#
# # electricity.csv, pred_len=192, Reformer
# constraint_level:
#   values: [0.184, 0.185, 0.187]
# model:
#   value: Reformer
#
# # electricity.csv, pred_len=336, Autoformer
# constraint_level:
#   values: [0.169, 0.179, 0.189]
# model:
#   value: Autoformer
#
# # electricity.csv, pred_len=336, Informer
# constraint_level:
#   values: [0.22, 0.225, 0.233]
# model:
#   value: Informer
#
# # electricity.csv, pred_len=336, Reformer
# constraint_level:
#   values: [0.193, 0.194, 0.195]
# model:
#   value: Reformer
#
# # electricity.csv, pred_len=720, Autoformer
# constraint_level:
#   values: [0.201, 0.21, 0.224]
# model:
#   value: Autoformer
#
# # electricity.csv, pred_len=720, Informer
# constraint_level:
#   values: [0.341, 0.373, 0.426]
# model:
#   value: Informer
#
# # electricity.csv, pred_len=720, Reformer
# constraint_level:
#   values: [0.202, 0.205, 0.207]
# model:
#   value: Reformer
#
# # exchange_rate.csv, pred_len=96, Autoformer
# constraint_level:
#   values: [0.119, 0.174, 0.242]
# model:
#   value: Autoformer
#
# # exchange_rate.csv, pred_len=96, Informer
# constraint_level:
#   values: [0.052, 0.056, 0.059]
# model:
#   value: Informer
#
# # exchange_rate.csv, pred_len=96, Reformer
# constraint_level:
#   values: [0.096, 0.136, 0.175]
# model:
#   value: Reformer
#
# # exchange_rate.csv, pred_len=192, Autoformer
# constraint_level:
#   values: [0.22, 0.292, 0.377]
# model:
#   value: Autoformer
#
# # exchange_rate.csv, pred_len=192, Informer
# constraint_level:
#   values: [0.055, 0.057, 0.062]
# model:
#   value: Informer
#
# # exchange_rate.csv, pred_len=192, Reformer
# constraint_level:
#   values: [0.157, 0.238, 0.31]
# model:
#   value: Reformer
#
# # exchange_rate.csv, pred_len=336, Autoformer
# constraint_level:
#   values: [0.279, 0.396, 0.549]
# model:
#   value: Autoformer
#
# # exchange_rate.csv, pred_len=336, Informer
# constraint_level:
#   values: [0.061, 0.065, 0.069]
# model:
#   value: Informer
#
# # exchange_rate.csv, pred_len=336, Reformer
# constraint_level:
#   values: [0.236, 0.37, 0.484]
# model:
#   value: Reformer
#
# # exchange_rate.csv, pred_len=720, Autoformer
# constraint_level:
#   values: [0.418, 0.845, 1.153]
# model:
#   value: Autoformer
#
# # exchange_rate.csv, pred_len=720, Informer
# constraint_level:
#   values: [0.068, 0.072, 0.079]
# model:
#   value: Informer
#
# # exchange_rate.csv, pred_len=720, Reformer
# constraint_level:
#   values: [0.37, 0.593, 0.683]
# model:
#   value: Reformer
#
# # weather.csv, pred_len=96, Autoformer
# constraint_level:
#   values: [0.35, 0.372, 0.402]
# model:
#   value: Autoformer
#
# # weather.csv, pred_len=96, Informer
# constraint_level:
#   values: [0.238, 0.245, 0.251]
# model:
#   value: Informer
#
# # weather.csv, pred_len=96, Reformer
# constraint_level:
#   values: [0.314, 0.342, 0.362]
# model:
#   value: Reformer
#
# # weather.csv, pred_len=192, Autoformer
# constraint_level:
#   values: [0.397, 0.476, 0.663]
# model:
#   value: Autoformer
#
# # weather.csv, pred_len=192, Informer
# constraint_level:
#   values: [0.252, 0.258, 0.266]
# model:
#   value: Informer
#
# # weather.csv, pred_len=192, Reformer
# constraint_level:
#   values: [0.346, 0.367, 0.387]
# model:
#   value: Reformer
#
# # weather.csv, pred_len=336, Autoformer
# constraint_level:
#   values: [0.503, 0.564, 0.674]
# model:
#   value: Autoformer
#
# # weather.csv, pred_len=336, Informer
# constraint_level:
#   values: [0.263, 0.271, 0.28]
# model:
#   value: Informer
#
# # weather.csv, pred_len=336, Reformer
# constraint_level:
#   values: [0.366, 0.381, 0.394]
# model:
#   value: Reformer
#
# # weather.csv, pred_len=720, Autoformer
# constraint_level:
#   values: [0.685, 0.748, 0.777]
# model:
#   value: Autoformer
#
# # weather.csv, pred_len=720, Informer
# constraint_level:
#   values: [0.284, 0.289, 0.302]
# model:
#   value: Informer
#
# # weather.csv, pred_len=720, Reformer
# constraint_level:
#   values: [0.364, 0.369, 0.373]
# model:
#   value: Reformer
