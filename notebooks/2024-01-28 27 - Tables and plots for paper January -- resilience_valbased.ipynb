# %% [markdown]
# # 2024-01-26 23b - Tables and plots for paper January -- valbased.ipynb
# Refactor of notebook 15.

# %% [markdown]
# ## Parameters

# %%
EXPERIMENT_FOLDER_NAME='dev_icml_e16_19val'
FIGURES_FOLDER=f'../figures/{EXPERIMENT_FOLDER_NAME}'

# %% [markdown]
# ## Libraries and setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown, Latex

# %%
from utils import wandb_utils

# %%
# Creating necessary folders
if not os.path.exists(FIGURES_FOLDER):
    os.makedirs(FIGURES_FOLDER, exist_ok=True)

# %% [markdown]
# ## Data Download

# %%
df = wandb_utils.get_experiment_data("Autoformer","alelab",experiment_tags=[],query_dict={"$and": [
                        {"tags": {"$in": ["e16_finaljan_allerm_replicated","e19_icml_resilience_val"]}},
                        {"state": "finished"},
                        {"config.seed": 2021}
        ]})
# Out:
# 100%|██████████| 96/96 [07:09<00:00,  4.47s/it]
# Fetched 96 runs
# Total records: (96768, 85)
# Total runs: 96

# %%
df = raw_df.copy()
raw_df = df.copy()

# %%
# df = wandb_utils.get_experiment_data("Autoformer","alelab",experiment_tags=[
#     #"e16_finaljan_allerm_replicated",
#     "e19_icml_resilience_val",
# ])
# raw_df = df.copy() #as backup

# %%
#TODO deleteme
df = df[df.seed==2021].copy()
df.run_id.nunique()
# Out:
# 96

# %%
df.groupby(['data_path','model','pred_len','seed'])['run_id'].nunique().reset_index()
# Out:
#             data_path        model  pred_len  seed  run_id
# 0     electricity.csv   Autoformer        96  2021       2
# 1     electricity.csv   Autoformer       192  2021       2
# 2     electricity.csv   Autoformer       336  2021       2
# 3     electricity.csv   Autoformer       720  2021       2
# 4     electricity.csv     Informer        96  2021       2
# 5     electricity.csv     Informer       192  2021       2
# 6     electricity.csv     Informer       336  2021       2
# 7     electricity.csv     Informer       720  2021       2
# 8     electricity.csv     Reformer        96  2021       2
# 9     electricity.csv     Reformer       192  2021       2
# 10    electricity.csv     Reformer       336  2021       2
# 11    electricity.csv     Reformer       720  2021       2
# 12    electricity.csv  Transformer        96  2021       2
# 13    electricity.csv  Transformer       192  2021       2
# 14    electricity.csv  Transformer       336  2021       2
# 15    electricity.csv  Transformer       720  2021       2
# 16  exchange_rate.csv   Autoformer        96  2021       2
# 17  exchange_rate.csv   Autoformer       192  2021       2
# 18  exchange_rate.csv   Autoformer       336  2021       2
# 19  exchange_rate.csv   Autoformer       720  2021       2
# 20  exchange_rate.csv     Informer        96  2021       2
# 21  exchange_rate.csv     Informer       192  2021       2
# 22  exchange_rate.csv     Informer       336  2021       2
# 23  exchange_rate.csv     Informer       720  2021       2
# 24  exchange_rate.csv     Reformer        96  2021       2
# 25  exchange_rate.csv     Reformer       192  2021       2
# 26  exchange_rate.csv     Reformer       336  2021       2
# 27  exchange_rate.csv     Reformer       720  2021       2
# 28  exchange_rate.csv  Transformer        96  2021       2
# 29  exchange_rate.csv  Transformer       192  2021       2
# 30  exchange_rate.csv  Transformer       336  2021       2
# 31  exchange_rate.csv  Transformer       720  2021       2
# 32        weather.csv   Autoformer        96  2021       2
# 33        weather.csv   Autoformer       192  2021       2
# 34        weather.csv   Autoformer       336  2021       2
# 35        weather.csv   Autoformer       720  2021       2
# 36        weather.csv     Informer        96  2021       2
# 37        weather.csv     Informer       192  2021       2
# 38        weather.csv     Informer       336  2021       2
# 39        weather.csv     Informer       720  2021       2
# 40        weather.csv     Reformer        96  2021       2
# 41        weather.csv     Reformer       192  2021       2
# 42        weather.csv     Reformer       336  2021       2
# 43        weather.csv     Reformer       720  2021       2
# 44        weather.csv  Transformer        96  2021       2
# 45        weather.csv  Transformer       192  2021       2
# 46        weather.csv  Transformer       336  2021       2
# 47        weather.csv  Transformer       720  2021       2

# %% [markdown]
# ## Data processing
# This section contains processing specific to this experiment set. If you clone this notebook. Remove or refactor this section.

# %% [markdown]
# ### Label constraint_levels (`constraint_idx` column)
# useful for joining when the constraint values are different for each model.

# %%
# There are three constraint levels per run, add a rank column, sorted by constraint level.
df=df.copy()#df_constrained.copy()
#display(df[['seed','data_path','model','pred_len','constraint_level']].drop_duplicates().sort_values(['data_path','model','pred_len','constraint_level']).head())
df.loc[df.constraint_type=='resilience','constraint_idx'] = df.query('constraint_type=="resilience"').groupby(['seed','data_path','model','pred_len'])['constraint_level'].rank(method='dense', ascending=True).astype(int)
df.loc[df.constraint_type=='erm','constraint_idx'] = 0
df['constraint_idx'] = df['constraint_idx'].astype(int)
ranked_constraint_levels_summary = df[['run_id','data_path','model','pred_len','constraint_type','constraint_level','constraint_idx']].drop_duplicates('run_id').sort_values(['data_path','model','pred_len','constraint_level'])
print("Sanity checking on the summary")
ranked_constraint_levels_summary
# Out:
# Sanity checking on the summary
#          run_id        data_path        model  pred_len constraint_type  \
# 80352  uglzgsuo  electricity.csv   Autoformer        96             erm
# 31968  a7r7hvtb  electricity.csv   Autoformer        96      resilience
# 79776  j30xdff9  electricity.csv   Autoformer       192             erm
# 31392  5nlrqofg  electricity.csv   Autoformer       192      resilience
# 78768  0roswz2a  electricity.csv   Autoformer       336             erm
# ...         ...              ...          ...       ...             ...
# 35424  4cnizcvz      weather.csv  Transformer       192      resilience
# 82800  3pkwpeuw      weather.csv  Transformer       336             erm
# 34416  r8g1j1ud      weather.csv  Transformer       336      resilience
# 80640  2ldijjak      weather.csv  Transformer       720             erm
# 32256  389tqjsn      weather.csv  Transformer       720      resilience
#
#        constraint_level  constraint_idx
# 80352            -1.000               0
# 31968             0.160               1
# 79776            -1.000               0
# 31392             0.184               1
# 78768            -1.000               0
# ...                 ...             ...
# 35424             0.662               1
# 82800            -1.000               0
# 34416             0.772               1
# 80640            -1.000               0
# 32256             0.972               1
#
# [96 rows x 7 columns]

# %% [markdown]
# ### Broadcast ERM runs with constraint levels (`df_to_plot`)
# to compare ERM with constrained, we need every ERM run repeated to pair it with a constrained run.

# %%
df_erm.shape[0]
# Out:
# 48384

# %%
df_constrained.groupby(['data_path','model','pred_len','constraint_type'])['run_id'].nunique()
# Out:
# data_path          model        pred_len  constraint_type
# electricity.csv    Autoformer   96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Informer     96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Reformer     96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Transformer  96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
# exchange_rate.csv  Autoformer   96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Informer     96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Reformer     96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Transformer  96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
# weather.csv        Autoformer   96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Informer     96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Reformer     96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
#                    Transformer  96        resilience         1
#                                 192       resilience         1
#                                 336       resilience         1
#                                 720       resilience         1
# Name: run_id, dtype: int64

# %%
df_constrained = df.query('type=="Constrained"').copy()
df_erm = df.query('type=="ERM"').copy()
#(data_path,model,pred_len,constraint_level,constrained_unconstraled)
distinct_constraints = df_constrained[['data_path','model','pred_len','constraint_type']].drop_duplicates()

# crossjoin the ERM mse to all constraint levels
df_erm_w_broadcasted_constraint_levels = df_erm.drop(columns=['constraint_type']).merge(distinct_constraints,on=['data_path','model','pred_len'],how='left')
df_to_plot = pd.concat([df_constrained,df_erm_w_broadcasted_constraint_levels],axis=0)

# sanity check
display(df_erm_w_broadcasted_constraint_levels.shape)
print(f"Three constraints per experiment, broadcasted dataset size be equal to {df_erm.shape[0]*1}")
display(df_to_plot.shape)
print(f"Final dataset size should be equal to {df_constrained.shape[0]+df_erm.shape[0]*1}")
# Out:
# (48384, 86)
# Three constraints per experiment, broadcasted dataset size be equal to 48384
# (96768, 86)
# Final dataset size should be equal to 96768

# %% [markdown]
# ### Add constraint violation metric

# %%
# Adding the constraint violation column
df_to_plot["constraint_violation"] = (df_to_plot.mse-df_to_plot.constraint_level).clip(lower=0)
df_to_plot['is_infeasible'] = (df_to_plot.constraint_violation>0)*1

# sanity check
dd=df_to_plot[['run_id','model','type','step','mse','constraint_level','constraint_violation','is_infeasible']] 
print("For ERM")
display(dd.query('type=="ERM"').query('constraint_violation>0').head())
print("For Constrained")
display(dd.query('type=="Constrained"').query('constraint_violation>0').head())
# Out:
# For ERM
#      run_id        model type  step       mse  constraint_level  \
# 0  k6rl9exh  Transformer  ERM     0  0.095688              -1.0
# 1  k6rl9exh  Transformer  ERM     1  0.060131              -1.0
# 2  k6rl9exh  Transformer  ERM     2  0.058476              -1.0
# 3  k6rl9exh  Transformer  ERM     3  0.058762              -1.0
# 4  k6rl9exh  Transformer  ERM     4  0.058699              -1.0
#
#    constraint_violation  is_infeasible
# 0              1.095688              1
# 1              1.060131              1
# 2              1.058476              1
# 3              1.058762              1
# 4              1.058699              1
# For Constrained
#         run_id        model         type  step       mse  constraint_level  \
# 1729  fd08oovp  Transformer  Constrained   289  2.503312             2.496
# 1730  fd08oovp  Transformer  Constrained   290  2.535850             2.496
# 1731  fd08oovp  Transformer  Constrained   291  2.524903             2.496
# 1733  fd08oovp  Transformer  Constrained   293  2.563069             2.496
# 1734  fd08oovp  Transformer  Constrained   294  2.732760             2.496
#
#       constraint_violation  is_infeasible
# 1729              0.007312              1
# 1730              0.039850              1
# 1731              0.028903              1
# 1733              0.067069              1
# 1734              0.236760              1

# %% [markdown]
# ### Summary metrics per run (unused)
# Summarize all three runs into metrics per split by averaging mse and constraint levels.

# %%
# Calculate mean and std for mse and constraint_violation. Rename them mean_{metric} and std_{metric

summary_metrics_per_run = df_to_plot.groupby([
    "run_id",
    "Algorithm", #Harmless carryover col for legacy purposes (verified the counts are the same)
    "model",'type',"constraint_level","pred_len","data_path",
    "split"
    ])['mse','constraint_violation','infeasible_rate','run_id'].aggregate(
        mse=('mse','mean'),
        #std_mse=('mse','std'),
        mcv=('constraint_violation','mean'),
        #std_mcv=('constraint_violation','std'),
        mean_infeasible_rate=('infeasible_rate','mean'),
        #std_infeasible_rate=('infeasible_rate','std'),
        run_count=('run_id','nunique')
        ).reset_index().round(5)
summary_metrics = summary_metrics_per_run.groupby([
    "Algorithm", #Harmless carryover col for legacy purposes (verified the counts are the same)
    "model",'type',"constraint_level","pred_len","data_path",
    "split"]).aggregate(
        mse=('mse','mean'),
        std_mse=('mse','std'),
        mcv=('mcv','mean'),
        std_mcv=('mcv','std'),
        mean_infeasible_rate=('mean_infeasible_rate','mean'),
        std_infeasible_rate=('mean_infeasible_rate','std'),
        run_count=('run_count','mean')
    ).reset_index()
display(summary_metrics_per_run.shape)
display(summary_metrics.shape)
summary_metrics.head()
# Out:
# /home/jporras/miniconda3/envs/autoformer/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# (288, 12)
# (288, 14)
#                               Algorithm       model type  constraint_level  \
# 0  AllModels_electricity.csv Autoformer  Autoformer  ERM              -1.0
# 1  AllModels_electricity.csv Autoformer  Autoformer  ERM              -1.0
# 2  AllModels_electricity.csv Autoformer  Autoformer  ERM              -1.0
# 3  AllModels_electricity.csv Autoformer  Autoformer  ERM              -1.0
# 4  AllModels_electricity.csv Autoformer  Autoformer  ERM              -1.0
#
#    pred_len        data_path  split      mse  std_mse      mcv  std_mcv  \
# 0        96  electricity.csv   test  0.20399      NaN  1.20399      NaN
# 1        96  electricity.csv  train  0.11989      NaN  1.11989      NaN
# 2        96  electricity.csv    val  0.16142      NaN  1.16142      NaN
# 3       192  electricity.csv   test  0.21535      NaN  1.21535      NaN
# 4       192  electricity.csv  train  0.14774      NaN  1.14774      NaN
#
#    mean_infeasible_rate  std_infeasible_rate  run_count
# 0                   1.0                  NaN        1.0
# 1                   1.0                  NaN        1.0
# 2                   1.0                  NaN        1.0
# 3                   1.0                  NaN        1.0
# 4                   1.0                  NaN        1.0

# %% [markdown]
# **END OF PREPROCESSING**
#
# ---
# ---

# %% [markdown]
# ## Plots

# %% [markdown]
# ### ERM vs. Constrained on 50th percentile (one seed)
# TO DO: Reproduce the ERM vs constrained per model for each window size. Try to unify into one plot if possible.

# %%
# PARAMS
split="test"
constraint_idx = 1 # use the 50 percentile constraint to plot 1=25,2=50,3=75
seed=2021

# Filter
df_pct50_and_erm = df_to_plot[(df_to_plot.constraint_idx.isin([0,constraint_idx])) & (df_to_plot.seed==seed) & (df_to_plot.split==split)].copy()

PRED_LENS=sorted(df_to_plot.pred_len.unique().tolist())
#PRED_LENS=[96]
for pred_len in PRED_LENS:
    # Add data for constant line
    df_current_plot = df_pct50_and_erm.query('pred_len==@pred_len').copy()
    #constraint_level = df_current_plot.constraint_level.unique()[0]
    #df_current_plot['constraint_level'] = constraint_level
    display(Markdown(f"#### **ERM Vs Constrained {pred_len} (split={split}, constraint_idx={constraint_idx})**"))

    g = sns.FacetGrid(df_current_plot, col='model', row='data_path', hue='type', height=3, aspect=1.5, legend_out=True)
    #g.map(sns.lineplot, "step", "constraint_level", alpha=.7)
    g.map(sns.scatterplot, "step", "mse", alpha=.7)
    g.add_legend()
    #TODO fix and uncomment
    #g.savefig(f"{FIGURES_FOLDER}/constrained_vs_erm_{pred_len}_{str(constraint_level).replace('.','')}.png")
    plt.show()
# Out:
# #### **ERM Vs Constrained 96 (split=test, constraint_idx=1)**
# #### **ERM Vs Constrained 192 (split=test, constraint_idx=1)**
# #### **ERM Vs Constrained 336 (split=test, constraint_idx=1)**
# #### **ERM Vs Constrained 720 (split=test, constraint_idx=1)**

# %% [markdown]
# ### Multipliers over the window

# %%
# PARAMS
split="train"
constraint_idx = 2 # use the 50 percentile constraint to plot 1=25,2=50,3=75
seed=2021

# Filter
df_pct50 = df_to_plot[
    (df_to_plot.constraint_idx.isin([0,constraint_idx])) 
    & (df_to_plot.seed==seed) & (df_to_plot.split==split)
    & (df_to_plot.constraint_type=="resilience")
    ].copy()

PRED_LENS=sorted(df_to_plot.pred_len.unique().tolist())
#PRED_LENS=[96]
for pred_len in PRED_LENS:
    # Add data for constant line
    df_current_plot = df_pct50.query('pred_len==@pred_len').copy()
    #constraint_level = df_current_plot.constraint_level.unique()[0]
    #df_current_plot['constraint_level'] = constraint_level
    display(Markdown(f"#### **Multipliers vs loss {pred_len} (split={split}, constraint_idx={constraint_idx})**"))

    g = sns.FacetGrid(df_current_plot, col='model', row='data_path', height=3, aspect=1.5, legend_out=True)
    # Plot multipliers and MSEs
    g.map(sns.scatterplot, "step", "mse", alpha=.7,color='blue',label='MSE')
    g.map(sns.scatterplot, "step", "multiplier", alpha=.7,color='red',label='Multiplier')
    # Add legend the series

    g.add_legend()
    #g.savefig(f"{FIGURES_FOLDER}/constrained_vs_erm_{pred_len}_{str(constraint_level).replace('.','')}.png")
    plt.show()
# Out:
# #### **Multipliers vs loss 96 (split=train, constraint_idx=2)**
# #### **Multipliers vs loss 192 (split=train, constraint_idx=2)**
# #### **Multipliers vs loss 336 (split=train, constraint_idx=2)**
# #### **Multipliers vs loss 720 (split=train, constraint_idx=2)**

# %% [markdown]
# ### (old) ERM vs constrained

# %%
from IPython.display import display, Markdown
to_plot = df_to_plot[(df_to_plot.split=='test')].copy()
for (data_path,pred_len), series in to_plot.groupby(['data_path',"pred_len"]):
    constraints = series.constraint_level.unique()
    print(constraints)
    constraints = constraints[constraints!=-1] # to iterate over all constraints explored.
    for constraint_level in constraints:
        display(Markdown(f"### Dataset: {data_path} pred_len: {pred_len} constraint_level: {constraint_level}"))
        plot_series = series[series["constraint_level"]==constraint_level]
        
        #means_per_experiment = plot_series.groupby(['pred_len','constraint_level','Algorithm','model','epoch','type'])['mse'].mean().reset_index()
        #display(means_per_experiment)
        # do a pivot where model are the rows, and the columns constrained and unconstrained
        #display(means_per_experiment.pivot(index=['model'], columns='type', values='mse').reset_index())

        # sns.scatterplot(x="step", y="mse", hue="Algorithm",style="split", data=plot_series)
        
        # plt.axhline(y=constraint_level, color='r', linestyle='-')
        # plt.title(f"Pred Length: {pred_len}, Constraint_level: {constraint_level}")
        # plt.show()

        # This same scatterplot but in a grid by algorithm. 
        g = sns.FacetGrid(plot_series, col="model", hue="type",col_wrap=3)
        g.map(sns.scatterplot, "step", "mse", alpha=.7) 
        g.add_legend()
        # add the hline
        for ax in g.axes:
            ax.axhline(y=constraint_level, color='r', linestyle='-')
        plt.show()
        # export this plot to latex. Remove the dot in constraint_level decimal
        #TODO fix
        #g.savefig(f"{FIGURES_FOLDER}/constrained_vs_erm_{data_path.replace('.','')}_{pred_len}_{str(constraint_level).replace('.','')}.png")
        # Fix [Errno 2] No such file or directory: 'figures/electricity.csv_96_0.17_individual.png'
# Out:
# [ 0.181  0.226  0.202  0.16  -1.   ]
# ### Dataset: electricity.csv pred_len: 96 constraint_level: 0.181
# ### Dataset: electricity.csv pred_len: 96 constraint_level: 0.226
# ### Dataset: electricity.csv pred_len: 96 constraint_level: 0.202
# ### Dataset: electricity.csv pred_len: 96 constraint_level: 0.16
# [ 0.211  0.237  0.238  0.184 -1.   ]
# ### Dataset: electricity.csv pred_len: 192 constraint_level: 0.211
# ### Dataset: electricity.csv pred_len: 192 constraint_level: 0.237
# ### Dataset: electricity.csv pred_len: 192 constraint_level: 0.238
# ### Dataset: electricity.csv pred_len: 192 constraint_level: 0.184
# [ 0.211  0.263  0.236  0.207 -1.   ]
# ### Dataset: electricity.csv pred_len: 336 constraint_level: 0.211
# ### Dataset: electricity.csv pred_len: 336 constraint_level: 0.263
# ### Dataset: electricity.csv pred_len: 336 constraint_level: 0.236
# ### Dataset: electricity.csv pred_len: 336 constraint_level: 0.207
# [ 0.239  0.321  0.254  0.228 -1.   ]
# ### Dataset: electricity.csv pred_len: 720 constraint_level: 0.239
# ### Dataset: electricity.csv pred_len: 720 constraint_level: 0.321
# ### Dataset: electricity.csv pred_len: 720 constraint_level: 0.254
# ### Dataset: electricity.csv pred_len: 720 constraint_level: 0.228
# [ 0.562  0.8    1.221  0.217 -1.   ]
# ### Dataset: exchange_rate.csv pred_len: 96 constraint_level: 0.562
# ### Dataset: exchange_rate.csv pred_len: 96 constraint_level: 0.8
# ### Dataset: exchange_rate.csv pred_len: 96 constraint_level: 1.221
# ### Dataset: exchange_rate.csv pred_len: 96 constraint_level: 0.217
# [ 0.798  1.103  2.067  0.742 -1.   ]
# ### Dataset: exchange_rate.csv pred_len: 192 constraint_level: 0.798
# ### Dataset: exchange_rate.csv pred_len: 192 constraint_level: 1.103
# ### Dataset: exchange_rate.csv pred_len: 192 constraint_level: 2.067
# ### Dataset: exchange_rate.csv pred_len: 192 constraint_level: 0.742
# [ 1.183  2.337  4.134  0.83  -1.   ]
# ### Dataset: exchange_rate.csv pred_len: 336 constraint_level: 1.183
# ### Dataset: exchange_rate.csv pred_len: 336 constraint_level: 2.337
# ### Dataset: exchange_rate.csv pred_len: 336 constraint_level: 4.134
# ### Dataset: exchange_rate.csv pred_len: 336 constraint_level: 0.83
# [ 2.496  4.829  4.638  1.047 -1.   ]
# ### Dataset: exchange_rate.csv pred_len: 720 constraint_level: 2.496
# ### Dataset: exchange_rate.csv pred_len: 720 constraint_level: 4.829
# ### Dataset: exchange_rate.csv pred_len: 720 constraint_level: 4.638
# ### Dataset: exchange_rate.csv pred_len: 720 constraint_level: 1.047
# [ 0.538  0.527  0.541 -1.   ]
# ### Dataset: weather.csv pred_len: 96 constraint_level: 0.538
# ### Dataset: weather.csv pred_len: 96 constraint_level: 0.527
# ### Dataset: weather.csv pred_len: 96 constraint_level: 0.541
# [ 0.662  0.563  0.627  0.58  -1.   ]
# ### Dataset: weather.csv pred_len: 192 constraint_level: 0.662
# ### Dataset: weather.csv pred_len: 192 constraint_level: 0.563
# ### Dataset: weather.csv pred_len: 192 constraint_level: 0.627
# ### Dataset: weather.csv pred_len: 192 constraint_level: 0.58
# [ 0.772  0.671  0.804  0.679 -1.   ]
# ### Dataset: weather.csv pred_len: 336 constraint_level: 0.772
# ### Dataset: weather.csv pred_len: 336 constraint_level: 0.671
# ### Dataset: weather.csv pred_len: 336 constraint_level: 0.804
# ### Dataset: weather.csv pred_len: 336 constraint_level: 0.679
# [ 0.972  0.849  0.892  0.862 -1.   ]
# ### Dataset: weather.csv pred_len: 720 constraint_level: 0.972
# ### Dataset: weather.csv pred_len: 720 constraint_level: 0.849
# ### Dataset: weather.csv pred_len: 720 constraint_level: 0.892
# ### Dataset: weather.csv pred_len: 720 constraint_level: 0.862

# %% [markdown]
# ### ERM on multiple algorithms
# As a front page chart to illustrate the problem

# %%
#TODO ( I think Nacho already did this)

# %% [markdown]
# ### Loss shaping single instance qualitative analysis

# %% [markdown]
# ### Plotting dual variables

# %%
df_to_plot[['run_id','pred_len','constraint_level','data_path','model','type']].drop_duplicates().query("data_path=='weather.csv' and model=='Reformer' and type=='Constrained'")
# Out:
#          run_id  pred_len  constraint_level    data_path     model  \
# 68544  p9izzn2r        96             0.556  weather.csv  Reformer
# 68832  b1adswkj        96             0.553  weather.csv  Reformer
# 69120  dowv2wrc        96             0.516  weather.csv  Reformer
# 69408  i7gx5ivx       192             0.665  weather.csv  Reformer
# 69984  v4rwuch4       192             0.567  weather.csv  Reformer
# 70560  mitm69y2       192             0.553  weather.csv  Reformer
# 71136  chbkcq99       336             0.970  weather.csv  Reformer
# 72144  749ywu49       336             0.741  weather.csv  Reformer
# 73152  fe29o3il       336             0.682  weather.csv  Reformer
# 74160  n1dluqy8       720             0.912  weather.csv  Reformer
# 76320  ds6fdrqd       720             0.862  weather.csv  Reformer
# 78480  f11og493       720             0.698  weather.csv  Reformer
#
#               type
# 68544  Constrained
# 68832  Constrained
# 69120  Constrained
# 69408  Constrained
# 69984  Constrained
# 70560  Constrained
# 71136  Constrained
# 72144  Constrained
# 73152  Constrained
# 74160  Constrained
# 76320  Constrained
# 78480  Constrained

# %%
constrained_runs = df_to_plot.query('type=="Constrained"').copy()
# Sum the multilpiers, fill with 0
key_cols=['run_id','model','pred_len','constraint_level','data_path']
multiplier_sum=constrained_runs.groupby(key_cols)['multiplier'].sum().reset_index()

#TO DO: plot MSE 
# get test mse
test_mses=constrained_runs.query('split=="test"').groupby(key_cols)['mse'].mean().reset_index()
mult_vs_test_mse=multiplier_sum.merge(test_mses,on=key_cols)
#sns.scatterplot(x="multiplier", y="mse", hue="constraint_level",style="pred_len", data=mult_vs_test_mse)
#g = sns.FacetGrid(mult_vs_test_mse, col="model",row='data_path',style="pred_len")
# scatterplot with hue="constraint_level",style="pred_len"
#g.map(sns.scatterplot, "multiplier", "mse", alpha=.7,)#sns.scatterplot(**args,hue="constraint_level",style="pred_len",alpha=0.3)
#g.map(sns.scatterplot, "multiplier", "mse",alpha=.7)

# %%
# #df_to_plot.query('split=="train" and pred_len==96').run_id.head(1)
# #mult_cols = [f"multiplier/{i}" for i in range(0,96)]
# # Plot for every constraint level in the 96 pred len window
# #for pred_len in df_to_plot.pred_len.unique():
# display(Markdown(f"# Multipliers for window of {pred_len}"))
# # sns.scatterplot(x="step", y="multiplier", hue="model",style="constraint_level", 
# #     data=df_to_plot.query(f"split=='train' and type=='Constrained' and pred_len=={96} and data_path=='weather.csv'"))
# # same plot, but grid with one plot per model
# dd = df_to_plot#df_to_plot.query("run_id=='6fgam2dx' and split=='train'")#.query(f"split=='train' and type=='Constrained' and pred_len==96 and data_path=='electricity.csv' and model=='Reformer' and constraint_level==0.157")
# dd_test = df_to_plot#df_to_plot.query("run_id=='6fgam2dx' and split=='test'")#.query(f"split=='test' and type=='Constrained' and pred_len==96 and data_path=='electricity.csv' and model=='Reformer' and constraint_level==0.157")

# #print(dd_test.constraint_level.unique())
# test_set_plus_multipliers = dd[['step','multiplier']].merge(dd_test[['step','split','mse']],on='step')

# unioned = pd.concat([dd[['step','split','multiplier','mse']],test_set_plus_multipliers[['step','split','multiplier','mse']]])

# display(unioned)


# display(test_set_plus_multipliers)

# #constraint_level==0.553
# # mult on x, mse@train and mse@test on y. hue=split
# # Add step over every point
# sns.scatterplot(unioned,x="multiplier", y="mse",hue='split', alpha=.3,legend='full')



# g = sns.FacetGrid(dd, col="model", row="constraint_level")
# g.map(sns.scatterplot, "step", "multiplier", alpha=.3)
# #g.map(sns.scatterplot, "step", "mse", alpha=.3)
# Out:
# # Multipliers for window of 720
#           step  split  multiplier       mse
# 16128        0  train    2.801533  0.209369
# 16129        1  train    1.050123  0.204042
# 16130        2  train    0.269966  0.194581
# 16131        3  train    0.000000  0.189056
# 16132        4  train    0.000000  0.187635
# ...        ...    ...         ...       ...
# 17418235   719   test         NaN  1.910884
# 17418236   719   test         NaN  1.910884
# 17418237   719    val         NaN  1.909591
# 17418238   719    val         NaN  1.909591
# 17418239   719    val         NaN  1.909591
#
# [17515008 rows x 4 columns]
#           step  multiplier  split       mse
# 0            0    2.801533  train  0.209369
# 1            0    2.801533   test  0.268508
# 2            0    2.801533    val  0.266284
# 3            0    2.801533  train  0.215619
# 4            0    2.801533   test  0.247226
# ...        ...         ...    ...       ...
# 17418235   719         NaN   test  1.910884
# 17418236   719         NaN   test  1.910884
# 17418237   719         NaN    val  1.909591
# 17418238   719         NaN    val  1.909591
# 17418239   719         NaN    val  1.909591
#
# [17418240 rows x 4 columns]
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fedbc19fa70> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2844             self.patch.draw(renderer)
#    2845             mimage._draw_list_compositing_images(
# -> 2846                 renderer, self, artists, self.suppressComposite)
#    2847
#    2848             for sfig in self.subfigs:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3090
#    3091         mimage._draw_list_compositing_images(
# -> 3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#    3094         renderer.close_group('axes')
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     988     def draw(self, renderer):
#     989         self.set_sizes(self._sizes, self.figure.dpi)
# --> 990         super().draw(renderer)
#     991
#     992
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     428                 self._linewidths, self._linestyles,
#     429                 self._antialiaseds, self._urls,
# --> 430                 self._offset_position)
#     431
#     432         gc.restore()
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/path.py in vertices(self)
#     198         )
#     199
# --> 200     @property
#     201     def vertices(self):
#     202         """
#
# KeyboardInterrupt:
# /home/jporras/miniconda3/envs/autoformer/lib/python3.7/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Error in callback <function flush_figures at 0x7fedbc19f4d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      90             display(
#      91                 figure_manager.canvas.figure,
# ---> 92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93             )
#      94     finally:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2323                         orientation=orientation,
#    2324                         bbox_inches_restore=_bbox_inches_restore,
# -> 2325                         **kwargs)
#    2326             finally:
#    2327                 if bbox_inches and restore_bbox:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2844             self.patch.draw(renderer)
#    2845             mimage._draw_list_compositing_images(
# -> 2846                 renderer, self, artists, self.suppressComposite)
#    2847
#    2848             for sfig in self.subfigs:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3090
#    3091         mimage._draw_list_compositing_images(
# -> 3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#    3094         renderer.close_group('axes')
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     988     def draw(self, renderer):
#     989         self.set_sizes(self._sizes, self.figure.dpi)
# --> 990         super().draw(renderer)
#     991
#     992
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     428                 self._linewidths, self._linestyles,
#     429                 self._antialiaseds, self._urls,
# --> 430                 self._offset_position)
#     431
#     432         gc.restore()
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/matplotlib/path.py in vertices(self)
#     198         )
#     199
# --> 200     @property
#     201     def vertices(self):
#     202         """
#
# KeyboardInterrupt:

# %% [markdown]
# ### More random explorations
# Ideas:
# 1. Loss over time
# 2. Infeasibility rate over time
# 3. Loss shape across epochs (see how it evolves)
# 4. Plotting dual variables

# %% [markdown]
# ## Result tables
# 1. Reproduce the pivot table from notebook 11, perhaps add standard deviation reports.
# 2. Explore and find other interesting table visualziation

# %% [markdown]
# ### Pivot tables (summary)

# %%
#Note, variance is nan because there is only one run per parameter set
weather = summary_metrics.query('data_path=="weather.csv"').copy()
electricity = summary_metrics.query('data_path=="electricity.csv"').copy()
for name,dataset in [('weather',weather), ('electricity',electricity)]:
    display(Markdown(f"# {name}"))
    tp2=dataset.copy(deep=True)
    #tp2=weather.query('split=="test"').copy()
    # Compute 'infeasible amount' as the difference between the mse and the constraint_level, 0 if mse < constraint
    #tp2['mean_violation']=tp2.apply(lambda x: max(0,x['mse']-x['constraint_level']),axis=1)
    
    # Split into constrained and ERM
    tp2_constrained=tp2.query('type=="Constrained"').copy()
    tp2_erm_baseline=tp2.query('type=="ERM"').copy()

    distinct_constraints = tp2_constrained[['pred_len','model','constraint_level']].drop_duplicates()

    # crossjoin the ERM mse to all constraint levels
    #tp2_erm_baseline_broadcasted = tp2_erm_baseline.drop(columns=['constraint_level']).merge(distinct_constraints,on=['pred_len','model'],how='left')

    #display(tp2_erm_baseline_broadcasted[['type','model','constraint_level','mse']].head())

    # concat back together to compute mean_violation
    #tp2=pd.concat([tp2_constrained,tp2_erm_baseline_broadcasted],axis=0)

    #tp2['mean_violation']=tp2.apply(lambda x: max(0,x['mse']-x['constraint_level']),axis=1)

    # Sanity check show the mean_violation for the ERM runs
    #display(tp2.query('type=="ERM"')[['type','model','constraint_level','mse','mean_violation']].head())


    #GROUPING TEH VALS
    grouped_values=tp2.groupby(['pred_len','constraint_level','model','type'])[[
        'mse','mcv',
        'std_mse','std_mcv',
        'mean_infeasible_rate','std_infeasible_rate']].mean().reset_index()
    #grouped_constrained = grouped_values[grouped_values.type=='Constrained'].copy()
    #grouped_erm_baseline=grouped_values[grouped_values.type=='ERM'].copy()

    # best_constraints is the constraint for each model and pred_len that minimizes mean_violation. show min and argmin
    #best_constraints_per_window = grouped_values.query('type=="Constrained"').groupby(['pred_len']).apply(lambda x: x.loc[x['mean_violation'].idxmin()]).reset_index(drop=True)[['pred_len','type','constraint_level','mean_violation','mse']]
    # instead of best constraints, show all constraint levels.

    # join best_constraints and grouped_values to get the mse and mean_violation for the best constraint
    #best_constrained=grouped_values.merge(best_constraints_per_window[['pred_len','constraint_level']],on=['pred_len','constraint_level'],how='inner')


    # crossjoin the ERM mse to all constraint levels
    ##grouped_erm_baseline_broadcasted = grouped_erm_baseline.drop(columns=['constraint_level']).merge(grouped_constrained[['pred_len','model','constraint_level']].drop_duplicates(),on=['pred_len','model'],how='left')

    # Pivot of models versus constrained and ERM, values are mse and mse_diff
    all_results = grouped_values#pd.concat([grouped_constrained,grouped_erm_baseline_broadcasted],axis=0)
    # Pivot all results, sort ascending by pred_len, then mean_violation on constrained

    pivoted=all_results.pivot(
        index=['pred_len','constraint_level'], 
        columns=['type','model'], 
        values=['mse','std_mse','mcv','std_mcv','mean_infeasible_rate','std_infeasible_rate']
    ).query('constraint_level>0').round(4)
    simplified = all_results.pivot(
        index=['pred_len','constraint_level'],
        columns=['type','model'],
        values=['mse','mcv']
    )
    pd.set_option('display.max_columns', None)
    print("SIMPLIFIED 192 MSE")
    # show all pred lengths (index)
    for pred_len in [96, 192, 336, 720]:            
        print(simplified.index.get_level_values(0).unique())
        simp_mse_192=simplified[simplified.index.get_level_values(0)==pred_len][['mse']]
        sim_mcv_192=simplified[simplified.index.get_level_values(0)==pred_len][['mcv']]

        # Flatten the multiindex
        def prettify(d):
            d = d.copy()
            d.columns = d.columns.map('_'.join)
            return d.style.format(precision=3)
        # display(prettify(simp_mse_192))
        print(f"SIMPLIFIED {pred_len} MCV")
        display(prettify(sim_mcv_192))
    print("FULL")
    display(pivoted)
    #reformer works best on weather.
# Out:
# # weather
# SIMPLIFIED 192 MSE
# Int64Index([96, 192, 336, 720], dtype='int64', name='pred_len')
# SIMPLIFIED 96 MCV
# <style type="text/css">
# </style>
# <table id="T_047e2_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mcv_Constrained_Transformer</th>
#       <th class="col_heading level0 col1" >mcv_ERM_Transformer</th>
#       <th class="col_heading level0 col2" >mcv_Constrained_Informer</th>
#       <th class="col_heading level0 col3" >mcv_ERM_Informer</th>
#       <th class="col_heading level0 col4" >mcv_Constrained_Autoformer</th>
#       <th class="col_heading level0 col5" >mcv_ERM_Autoformer</th>
#       <th class="col_heading level0 col6" >mcv_Constrained_Reformer</th>
#       <th class="col_heading level0 col7" >mcv_ERM_Reformer</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pred_len</th>
#       <th class="index_name level1" >constraint_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_047e2_level0_row0" class="row_heading level0 row0" rowspan="9">96</th>
#       <th id="T_047e2_level1_row0" class="row_heading level1 row0" >0.467</th>
#       <td id="T_047e2_row0_col0" class="data row0 col0" >0.035</td>
#       <td id="T_047e2_row0_col1" class="data row0 col1" >0.036</td>
#       <td id="T_047e2_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_047e2_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_047e2_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_047e2_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_047e2_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_047e2_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row1" class="row_heading level1 row1" >0.475</th>
#       <td id="T_047e2_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_047e2_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_047e2_row1_col2" class="data row1 col2" >0.018</td>
#       <td id="T_047e2_row1_col3" class="data row1 col3" >0.024</td>
#       <td id="T_047e2_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_047e2_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_047e2_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_047e2_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row2" class="row_heading level1 row2" >0.484</th>
#       <td id="T_047e2_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_047e2_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_047e2_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_047e2_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_047e2_row2_col4" class="data row2 col4" >0.016</td>
#       <td id="T_047e2_row2_col5" class="data row2 col5" >0.019</td>
#       <td id="T_047e2_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_047e2_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row3" class="row_heading level1 row3" >0.527</th>
#       <td id="T_047e2_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_047e2_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_047e2_row3_col2" class="data row3 col2" >0.005</td>
#       <td id="T_047e2_row3_col3" class="data row3 col3" >0.007</td>
#       <td id="T_047e2_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_047e2_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_047e2_row3_col6" class="data row3 col6" >0.003</td>
#       <td id="T_047e2_row3_col7" class="data row3 col7" >0.005</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row4" class="row_heading level1 row4" >0.538</th>
#       <td id="T_047e2_row4_col0" class="data row4 col0" >0.006</td>
#       <td id="T_047e2_row4_col1" class="data row4 col1" >0.011</td>
#       <td id="T_047e2_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_047e2_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_047e2_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_047e2_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_047e2_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_047e2_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row5" class="row_heading level1 row5" >0.548</th>
#       <td id="T_047e2_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_047e2_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_047e2_row5_col2" class="data row5 col2" >0.001</td>
#       <td id="T_047e2_row5_col3" class="data row5 col3" >0.004</td>
#       <td id="T_047e2_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_047e2_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_047e2_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_047e2_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row6" class="row_heading level1 row6" >0.549</th>
#       <td id="T_047e2_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_047e2_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_047e2_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_047e2_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_047e2_row6_col4" class="data row6 col4" >0.000</td>
#       <td id="T_047e2_row6_col5" class="data row6 col5" >0.003</td>
#       <td id="T_047e2_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_047e2_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row7" class="row_heading level1 row7" >0.565</th>
#       <td id="T_047e2_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_047e2_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_047e2_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_047e2_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_047e2_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_047e2_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_047e2_row7_col6" class="data row7 col6" >0.001</td>
#       <td id="T_047e2_row7_col7" class="data row7 col7" >0.001</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level1_row8" class="row_heading level1 row8" >0.585</th>
#       <td id="T_047e2_row8_col0" class="data row8 col0" >0.000</td>
#       <td id="T_047e2_row8_col1" class="data row8 col1" >0.002</td>
#       <td id="T_047e2_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_047e2_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_047e2_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_047e2_row8_col5" class="data row8 col5" >nan</td>
#       <td id="T_047e2_row8_col6" class="data row8 col6" >nan</td>
#       <td id="T_047e2_row8_col7" class="data row8 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Int64Index([96, 192, 336, 720], dtype='int64', name='pred_len')
# SIMPLIFIED 192 MCV
# <style type="text/css">
# </style>
# <table id="T_c1f25_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mcv_Constrained_Transformer</th>
#       <th class="col_heading level0 col1" >mcv_ERM_Transformer</th>
#       <th class="col_heading level0 col2" >mcv_Constrained_Informer</th>
#       <th class="col_heading level0 col3" >mcv_ERM_Informer</th>
#       <th class="col_heading level0 col4" >mcv_Constrained_Autoformer</th>
#       <th class="col_heading level0 col5" >mcv_ERM_Autoformer</th>
#       <th class="col_heading level0 col6" >mcv_Constrained_Reformer</th>
#       <th class="col_heading level0 col7" >mcv_ERM_Reformer</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pred_len</th>
#       <th class="index_name level1" >constraint_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1f25_level0_row0" class="row_heading level0 row0" rowspan="10">192</th>
#       <th id="T_c1f25_level1_row0" class="row_heading level1 row0" >0.525</th>
#       <td id="T_c1f25_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_c1f25_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_c1f25_row0_col2" class="data row0 col2" >0.024</td>
#       <td id="T_c1f25_row0_col3" class="data row0 col3" >0.037</td>
#       <td id="T_c1f25_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_c1f25_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_c1f25_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_c1f25_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row1" class="row_heading level1 row1" >0.559</th>
#       <td id="T_c1f25_row1_col0" class="data row1 col0" >0.115</td>
#       <td id="T_c1f25_row1_col1" class="data row1 col1" >0.091</td>
#       <td id="T_c1f25_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_c1f25_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_c1f25_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_c1f25_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_c1f25_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_c1f25_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row2" class="row_heading level1 row2" >0.563</th>
#       <td id="T_c1f25_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_c1f25_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_c1f25_row2_col2" class="data row2 col2" >0.010</td>
#       <td id="T_c1f25_row2_col3" class="data row2 col3" >0.025</td>
#       <td id="T_c1f25_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_c1f25_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_c1f25_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_c1f25_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row3" class="row_heading level1 row3" >0.58</th>
#       <td id="T_c1f25_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_c1f25_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_c1f25_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_c1f25_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_c1f25_row3_col4" class="data row3 col4" >0.018</td>
#       <td id="T_c1f25_row3_col5" class="data row3 col5" >0.033</td>
#       <td id="T_c1f25_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_c1f25_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row4" class="row_heading level1 row4" >0.598</th>
#       <td id="T_c1f25_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_c1f25_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_c1f25_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_c1f25_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_c1f25_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_c1f25_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_c1f25_row4_col6" class="data row4 col6" >0.001</td>
#       <td id="T_c1f25_row4_col7" class="data row4 col7" >0.055</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row5" class="row_heading level1 row5" >0.607</th>
#       <td id="T_c1f25_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_c1f25_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_c1f25_row5_col2" class="data row5 col2" >0.011</td>
#       <td id="T_c1f25_row5_col3" class="data row5 col3" >0.016</td>
#       <td id="T_c1f25_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_c1f25_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_c1f25_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_c1f25_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row6" class="row_heading level1 row6" >0.627</th>
#       <td id="T_c1f25_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_c1f25_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_c1f25_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_c1f25_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_c1f25_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_c1f25_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_c1f25_row6_col6" class="data row6 col6" >0.001</td>
#       <td id="T_c1f25_row6_col7" class="data row6 col7" >0.042</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row7" class="row_heading level1 row7" >0.662</th>
#       <td id="T_c1f25_row7_col0" class="data row7 col0" >0.099</td>
#       <td id="T_c1f25_row7_col1" class="data row7 col1" >0.053</td>
#       <td id="T_c1f25_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_c1f25_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_c1f25_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_c1f25_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_c1f25_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_c1f25_row7_col7" class="data row7 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row8" class="row_heading level1 row8" >0.667</th>
#       <td id="T_c1f25_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_c1f25_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_c1f25_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_c1f25_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_c1f25_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_c1f25_row8_col5" class="data row8 col5" >nan</td>
#       <td id="T_c1f25_row8_col6" class="data row8 col6" >0.001</td>
#       <td id="T_c1f25_row8_col7" class="data row8 col7" >0.027</td>
#     </tr>
#     <tr>
#       <th id="T_c1f25_level1_row9" class="row_heading level1 row9" >0.771</th>
#       <td id="T_c1f25_row9_col0" class="data row9 col0" >0.063</td>
#       <td id="T_c1f25_row9_col1" class="data row9 col1" >0.027</td>
#       <td id="T_c1f25_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_c1f25_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_c1f25_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_c1f25_row9_col5" class="data row9 col5" >nan</td>
#       <td id="T_c1f25_row9_col6" class="data row9 col6" >nan</td>
#       <td id="T_c1f25_row9_col7" class="data row9 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Int64Index([96, 192, 336, 720], dtype='int64', name='pred_len')
# SIMPLIFIED 336 MCV
# <style type="text/css">
# </style>
# <table id="T_0cb8b_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mcv_Constrained_Transformer</th>
#       <th class="col_heading level0 col1" >mcv_ERM_Transformer</th>
#       <th class="col_heading level0 col2" >mcv_Constrained_Informer</th>
#       <th class="col_heading level0 col3" >mcv_ERM_Informer</th>
#       <th class="col_heading level0 col4" >mcv_Constrained_Autoformer</th>
#       <th class="col_heading level0 col5" >mcv_ERM_Autoformer</th>
#       <th class="col_heading level0 col6" >mcv_Constrained_Reformer</th>
#       <th class="col_heading level0 col7" >mcv_ERM_Reformer</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pred_len</th>
#       <th class="index_name level1" >constraint_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cb8b_level0_row0" class="row_heading level0 row0" rowspan="11">336</th>
#       <th id="T_0cb8b_level1_row0" class="row_heading level1 row0" >0.577</th>
#       <td id="T_0cb8b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_0cb8b_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_0cb8b_row0_col2" class="data row0 col2" >0.064</td>
#       <td id="T_0cb8b_row0_col3" class="data row0 col3" >0.053</td>
#       <td id="T_0cb8b_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_0cb8b_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_0cb8b_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_0cb8b_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row1" class="row_heading level1 row1" >0.61</th>
#       <td id="T_0cb8b_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0cb8b_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_0cb8b_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_0cb8b_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_0cb8b_row1_col4" class="data row1 col4" >0.065</td>
#       <td id="T_0cb8b_row1_col5" class="data row1 col5" >0.041</td>
#       <td id="T_0cb8b_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_0cb8b_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row2" class="row_heading level1 row2" >0.622</th>
#       <td id="T_0cb8b_row2_col0" class="data row2 col0" >0.142</td>
#       <td id="T_0cb8b_row2_col1" class="data row2 col1" >0.107</td>
#       <td id="T_0cb8b_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_0cb8b_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_0cb8b_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_0cb8b_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_0cb8b_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_0cb8b_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row3" class="row_heading level1 row3" >0.671</th>
#       <td id="T_0cb8b_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_0cb8b_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_0cb8b_row3_col2" class="data row3 col2" >0.053</td>
#       <td id="T_0cb8b_row3_col3" class="data row3 col3" >0.022</td>
#       <td id="T_0cb8b_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_0cb8b_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_0cb8b_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_0cb8b_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row4" class="row_heading level1 row4" >0.679</th>
#       <td id="T_0cb8b_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_0cb8b_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_0cb8b_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_0cb8b_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_0cb8b_row4_col4" class="data row4 col4" >0.013</td>
#       <td id="T_0cb8b_row4_col5" class="data row4 col5" >0.015</td>
#       <td id="T_0cb8b_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_0cb8b_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row5" class="row_heading level1 row5" >0.729</th>
#       <td id="T_0cb8b_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_0cb8b_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_0cb8b_row5_col2" class="data row5 col2" >0.041</td>
#       <td id="T_0cb8b_row5_col3" class="data row5 col3" >0.011</td>
#       <td id="T_0cb8b_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_0cb8b_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_0cb8b_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_0cb8b_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row6" class="row_heading level1 row6" >0.73</th>
#       <td id="T_0cb8b_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_0cb8b_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_0cb8b_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_0cb8b_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_0cb8b_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_0cb8b_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_0cb8b_row6_col6" class="data row6 col6" >0.005</td>
#       <td id="T_0cb8b_row6_col7" class="data row6 col7" >0.124</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row7" class="row_heading level1 row7" >0.772</th>
#       <td id="T_0cb8b_row7_col0" class="data row7 col0" >0.088</td>
#       <td id="T_0cb8b_row7_col1" class="data row7 col1" >0.048</td>
#       <td id="T_0cb8b_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_0cb8b_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_0cb8b_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_0cb8b_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_0cb8b_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_0cb8b_row7_col7" class="data row7 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row8" class="row_heading level1 row8" >0.804</th>
#       <td id="T_0cb8b_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_0cb8b_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_0cb8b_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_0cb8b_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_0cb8b_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_0cb8b_row8_col5" class="data row8 col5" >nan</td>
#       <td id="T_0cb8b_row8_col6" class="data row8 col6" >0.008</td>
#       <td id="T_0cb8b_row8_col7" class="data row8 col7" >0.083</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row9" class="row_heading level1 row9" >0.835</th>
#       <td id="T_0cb8b_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_0cb8b_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_0cb8b_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_0cb8b_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_0cb8b_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_0cb8b_row9_col5" class="data row9 col5" >nan</td>
#       <td id="T_0cb8b_row9_col6" class="data row9 col6" >0.009</td>
#       <td id="T_0cb8b_row9_col7" class="data row9 col7" >0.068</td>
#     </tr>
#     <tr>
#       <th id="T_0cb8b_level1_row10" class="row_heading level1 row10" >0.869</th>
#       <td id="T_0cb8b_row10_col0" class="data row10 col0" >0.052</td>
#       <td id="T_0cb8b_row10_col1" class="data row10 col1" >0.017</td>
#       <td id="T_0cb8b_row10_col2" class="data row10 col2" >nan</td>
#       <td id="T_0cb8b_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_0cb8b_row10_col4"
# Int64Index([96, 192, 336, 720], dtype='int64', name='pred_len')
# SIMPLIFIED 720 MCV
# <style type="text/css">
# </style>
# <table id="T_2e849_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mcv_Constrained_Transformer</th>
#       <th class="col_heading level0 col1" >mcv_ERM_Transformer</th>
#       <th class="col_heading level0 col2" >mcv_Constrained_Informer</th>
#       <th class="col_heading level0 col3" >mcv_ERM_Informer</th>
#       <th class="col_heading level0 col4" >mcv_Constrained_Autoformer</th>
#       <th class="col_heading level0 col5" >mcv_ERM_Autoformer</th>
#       <th class="col_heading level0 col6" >mcv_Constrained_Reformer</th>
#       <th class="col_heading level0 col7" >mcv_ERM_Reformer</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pred_len</th>
#       <th class="index_name level1" >constraint_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e849_level0_row0" class="row_heading level0 row0" rowspan="9">720</th>
#       <th id="T_2e849_level1_row0" class="row_heading level1 row0" >0.747</th>
#       <td id="T_2e849_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_2e849_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_2e849_row0_col2" class="data row0 col2" >0.422</td>
#       <td id="T_2e849_row0_col3" class="data row0 col3" >0.169</td>
#       <td id="T_2e849_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_2e849_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_2e849_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_2e849_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row1" class="row_heading level1 row1" >0.787</th>
#       <td id="T_2e849_row1_col0" class="data row1 col0" >0.245</td>
#       <td id="T_2e849_row1_col1" class="data row1 col1" >0.138</td>
#       <td id="T_2e849_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_2e849_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_2e849_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_2e849_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_2e849_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_2e849_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row2" class="row_heading level1 row2" >0.849</th>
#       <td id="T_2e849_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_2e849_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_2e849_row2_col2" class="data row2 col2" >0.415</td>
#       <td id="T_2e849_row2_col3" class="data row2 col3" >0.121</td>
#       <td id="T_2e849_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_2e849_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_2e849_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_2e849_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row3" class="row_heading level1 row3" >0.877</th>
#       <td id="T_2e849_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_2e849_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_2e849_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_2e849_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_2e849_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_2e849_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_2e849_row3_col6" class="data row3 col6" >0.060</td>
#       <td id="T_2e849_row3_col7" class="data row3 col7" >0.040</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row4" class="row_heading level1 row4" >0.892</th>
#       <td id="T_2e849_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_2e849_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_2e849_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_2e849_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_2e849_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_2e849_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_2e849_row4_col6" class="data row4 col6" >0.049</td>
#       <td id="T_2e849_row4_col7" class="data row4 col7" >0.031</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row5" class="row_heading level1 row5" >0.905</th>
#       <td id="T_2e849_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_2e849_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_2e849_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_2e849_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_2e849_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_2e849_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_2e849_row5_col6" class="data row5 col6" >0.050</td>
#       <td id="T_2e849_row5_col7" class="data row5 col7" >0.024</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row6" class="row_heading level1 row6" >0.972</th>
#       <td id="T_2e849_row6_col0" class="data row6 col0" >0.161</td>
#       <td id="T_2e849_row6_col1" class="data row6 col1" >0.057</td>
#       <td id="T_2e849_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_2e849_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_2e849_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_2e849_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_2e849_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_2e849_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row7" class="row_heading level1 row7" >0.98</th>
#       <td id="T_2e849_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_2e849_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_2e849_row7_col2" class="data row7 col2" >0.386</td>
#       <td id="T_2e849_row7_col3" class="data row7 col3" >0.075</td>
#       <td id="T_2e849_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_2e849_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_2e849_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_2e849_row7_col7" class="data row7 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e849_level1_row8" class="row_heading level1 row8" >1.035</th>
#       <td id="T_2e849_row8_col0" class="data row8 col0" >0.132</td>
#       <td id="T_2e849_row8_col1" class="data row8 col1" >0.036</td>
#       <td id="T_2e849_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_2e849_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_2e849_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_2e849_row8_col5" class="data row8 col5" >nan</td>
#       <td id="T_2e849_row8_col6" class="data row8 col6" >nan</td>
#       <td id="T_2e849_row8_col7" class="data row8 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# FULL
#                                   mse                                   \
# type                      Constrained         ERM Constrained      ERM
# model                     Transformer Transformer    Informer Informer
# pred_len constraint_level
# 96       0.467                 0.3932      0.3776         NaN      NaN
#          0.475                    NaN         NaN      0.3998   0.3836
#          0.484                    NaN         NaN         NaN      NaN
#          0.527                    NaN         NaN      0.4074   0.3836
#          0.538                 0.3869      0.3776         NaN      NaN
#          0.548                    NaN         NaN      0.3992   0.3836
#          0.549                    NaN         NaN         NaN      NaN
#          0.565                    NaN         NaN         NaN      NaN
#          0.585                 0.3870      0.3776         NaN      NaN
# 192      0.525                    NaN         NaN      0.4409   0.4364
#          0.559                 0.5479      0.5017         NaN      NaN
#          0.563                    NaN         NaN      0.4270   0.4364
#          0.580                    NaN         NaN         NaN      NaN
#          0.598                    NaN         NaN         NaN      NaN
#          0.607                    NaN         NaN      0.4409   0.4364
#          0.627                    NaN         NaN         NaN      NaN
#          0.662                 0.5888      0.5017         NaN      NaN
#          0.667                    NaN         NaN         NaN      NaN
#          0.771                 0.5986      0.5017         NaN      NaN
# 336      0.577                    NaN         NaN      0.5294   0.4980
#          0.610                    NaN         NaN         NaN      NaN
#          0.622                 0.6319      0.5636         NaN      NaN
#          0.671                    NaN         NaN      0.5439   0.4980
#          0.679                    NaN         NaN         NaN      NaN
#          0.729                    NaN         NaN      0.5609   0.4980
#          0.730                    NaN         NaN         NaN      NaN
#          0.772                 0.6517      0.5636         NaN      NaN
#          0.804                    NaN         NaN         NaN      NaN
#          0.835                    NaN         NaN         NaN      NaN
#          0.869                 0.6517      0.5636         NaN      NaN
# 720      0.747                    NaN         NaN      1.0187   0.7342
#          0.787                 0.8727      0.7018         NaN      NaN
#          0.849                    NaN         NaN      1.0665   0.7342
#          0.877                    NaN         NaN         NaN      NaN
#          0.892                    NaN         NaN         NaN      NaN
#          0.905                    NaN         NaN         NaN      NaN
#          0.972                 0.8927      0.7018         NaN      NaN
#          0.980                    NaN         NaN      1.0985   0.7342
#          1.035                 0.8925      0.7018         NaN      NaN
#
#                                                                        \
# type                      Constrained        ERM Constrained      ERM
# model                      Autoformer Autoformer    Reformer Reformer
# pred_len constraint_level
# 96       0.467                    NaN        NaN         NaN      NaN
#          0.475                    NaN        NaN         NaN      NaN
#          0.484                 0.4088     0.4086         NaN      NaN
#          0.527                    NaN        NaN      0.3965   0.4053
#          0.538                    NaN        NaN         NaN      NaN
#          0.548                    NaN        NaN         NaN      NaN
#          0.549                 0.4010     0.4086         NaN      NaN
#          0.565                    NaN        NaN      0.4071   0.4053
#          0.585                    NaN        NaN         NaN      NaN
# 192      0.525                    NaN        NaN         NaN      NaN
#          0.559                    NaN        NaN         NaN      NaN
#          0.563                    NaN        NaN         NaN      NaN
#          0.580                 0.4945     0.4814         NaN      NaN
#          0.598                    NaN        NaN      0.4497   0.5417
#          0.607                    NaN        NaN         NaN      NaN
#          0.627                    NaN        NaN      0.4615   0.5417
#          0.662                    NaN        NaN         NaN      NaN
#          0.667                    NaN        NaN      0.4798   0.5417
#          0.771                    NaN        NaN         NaN      NaN
# 336      0.577                    NaN        NaN         NaN      NaN
#          0.610                 0.6003     0.5351         NaN      NaN
#          0.622                    NaN        NaN         NaN      NaN
#          0.671                    NaN        NaN         NaN      NaN
#          0.679                 0.5487     0.5351         NaN      NaN
#          0.729                    NaN        NaN         NaN      NaN
#          0.730                    NaN        NaN      0.5566   0.7062
#          0.772                    NaN        NaN         NaN      NaN
#          0.804                    NaN        NaN      0.5993   0.7062
#          0.835                    NaN        NaN      0.6159   0.7062
#          0.869                    NaN        NaN         NaN      NaN
# 720      0.747                    NaN        NaN         NaN      NaN
#          0.787                    NaN        NaN         NaN      NaN
#          0.849                    NaN        NaN         NaN      NaN
#          0.877                    NaN        NaN      0.7519   0.7160
#          0.892                    NaN        NaN      0.7466   0.7160
#          0.905                    NaN        NaN      0.7548   0.7160
#          0.972                    NaN        NaN         NaN      NaN
#          0.980                    NaN        NaN         NaN      NaN
#          1.035                    NaN        NaN         NaN      NaN
#
#                               std_mse                                   \
# type                      Constrained         ERM Constrained      ERM
# model                     Transformer Transformer    Informer Informer
# pred_len constraint_level
# 96       0.467                    NaN         NaN         NaN      NaN
#          0.475                    NaN         NaN         NaN      NaN
#          0.484                    NaN         NaN         NaN      NaN
#          0.527                    NaN         NaN         NaN      NaN
#          0.538                    NaN         NaN         NaN      NaN
#          0.548                    NaN         NaN         NaN      NaN
#          0.549                    NaN         NaN         NaN      NaN
#          0.565                    NaN         NaN         NaN      NaN
#          0.585                    NaN         NaN         NaN      NaN
# 192      0.525                    NaN         NaN         NaN      NaN
#          0.559                    NaN         NaN         NaN      NaN
#          0.563                    NaN         NaN         NaN      NaN
#          0.580                    NaN         NaN         NaN      NaN
#          0.598                    NaN         NaN         NaN      NaN
#          0.607                    NaN         NaN         NaN      NaN
#          0.627                    NaN         NaN         NaN      NaN
#          0.662                    NaN         NaN         NaN      NaN
#          0.667                    NaN         NaN         NaN      NaN
#          0.771                    NaN         NaN         NaN      NaN
# 336      0.577                    NaN         NaN         NaN      NaN
#          0.610                    NaN         NaN         NaN      NaN
#          0.622                    NaN         NaN         NaN      NaN
#          0.671                    NaN         NaN         NaN      NaN
#          0.679                    NaN         NaN         NaN      NaN
#          0.729                    NaN         NaN         NaN      NaN
#          0.730                    NaN         NaN         NaN      NaN
#          0.772                    NaN         NaN         NaN      NaN
#          0.804                    NaN         NaN         NaN      NaN
#          0.835                    NaN         NaN         NaN      NaN
#          0.869                    NaN         NaN         NaN      NaN
# 720      0.747                    NaN         NaN         NaN      NaN
#          0.787                    NaN         NaN         NaN      NaN
#          0.849                    NaN         NaN         NaN      NaN
#          0.877                    NaN         NaN         NaN      NaN
#          0.892                    NaN         NaN         NaN      NaN
#          0.905                    NaN         NaN         NaN      NaN
#          0.972                    NaN         NaN         NaN      NaN
#          0.980                    NaN         NaN         NaN      NaN
#          1.035                    NaN         NaN         NaN      NaN
#
#                                                                        \
# type                      Constrained        ERM Constrained      ERM
# model                      Autoformer Autoformer    Reformer Reformer
# pred_len constraint_level
# 96       0.467                    NaN        NaN         NaN      NaN
#          0.475                    NaN        NaN         NaN      NaN
#          0.484                    NaN        NaN         NaN      NaN
#          0.527                    NaN        NaN         NaN      NaN
#          0.538                    NaN        NaN         NaN      NaN
#          0.548                    NaN        NaN         NaN      NaN
#          0.549                    NaN        NaN         NaN      NaN
#          0.565                    NaN        NaN         NaN      NaN
#          0.585                    NaN        NaN         NaN      NaN
# 192      0.525                    NaN        NaN         NaN      NaN
#          0.559                    NaN        NaN         NaN      NaN
#          0.563                    NaN        NaN         NaN      NaN
#          0.580                    NaN        NaN         NaN      NaN
#          0.598                    NaN        NaN         NaN      NaN
#          0.607                    NaN        NaN         NaN      NaN
#          0.627                    NaN        NaN         NaN      NaN
#          0.662                    NaN        NaN         NaN      NaN
#          0.667                    NaN        NaN         NaN      NaN
#          0.771                    NaN        NaN         NaN      NaN
# 336      0.577                    NaN        NaN         NaN      NaN
#          0.610                    NaN        NaN         NaN      NaN
#          0.622                    NaN        NaN         NaN      NaN
#          0.671                    NaN        NaN         NaN      NaN
#          0.679                    NaN        NaN         NaN      NaN
#          0.729                    NaN        NaN         NaN      NaN
#          0.730                    NaN        NaN         NaN      NaN
#          0.772                    NaN        NaN         NaN      NaN
#          0.804                    NaN        NaN         NaN      NaN
#          0.835                    NaN        NaN         NaN      NaN
#          0.869                    NaN        NaN         NaN      NaN
# 720      0.747                    NaN        NaN         NaN      NaN
#          0.787                    NaN        NaN         NaN      NaN
#          0.849                    NaN        NaN         NaN      NaN
#          0.877                    NaN        NaN         NaN      NaN
#          0.892                    NaN        NaN         NaN      NaN
#          0.905                    NaN        NaN         NaN      NaN
#          0.972                    NaN        NaN         NaN      NaN
#          0.980                    NaN        NaN         NaN      NaN
#          1.035                    NaN        NaN         NaN      NaN
#
#                                   mcv                                   \
# type                      Constrained         ERM Constrained      ERM
# model                     Transformer Transformer    Informer Informer
# pred_len constraint_level
# 96       0.467                 0.0346      0.0359         NaN      NaN
#          0.475                    NaN         NaN      0.0184   0.0244
#          0.484                    NaN         NaN         NaN      NaN
#          0.527                    NaN         NaN      0.0049   0.0073
#          0.538                 0.0058      0.0108         NaN      NaN
#          0.548                    NaN         NaN      0.0009   0.0036
#          0.549                    NaN         NaN         NaN      NaN
#          0.565                    NaN         NaN         NaN      NaN
#          0.585                 0.0005      0.0020         NaN      NaN
# 192      0.525                    NaN         NaN      0.0237   0.0372
#          0.559                 0.1153      0.0915         NaN      NaN
#          0.563                    NaN         NaN      0.0099   0.0246
#          0.580                    NaN         NaN         NaN      NaN
#          0.598                    NaN         NaN         NaN      NaN
#          0.607                    NaN         NaN      0.0109   0.0159
#          0.627                    NaN         NaN         NaN      NaN
#          0.662                 0.0990      0.0531         NaN      NaN
#          0.667                    NaN         NaN         NaN      NaN
#          0.771                 0.0626      0.0265         NaN      NaN
# 336      0.577                    NaN         NaN      0.0642   0.0527
#          0.610                    NaN         NaN         NaN      NaN
#          0.622                 0.1419      0.1071         NaN      NaN
#          0.671                    NaN         NaN      0.0529   0.0221
#          0.679                    NaN         NaN         NaN      NaN
#          0.729                    NaN         NaN      0.0406   0.0109
#          0.730                    NaN         NaN         NaN      NaN
#          0.772                 0.0876      0.0478         NaN      NaN
#          0.804                    NaN         NaN         NaN      NaN
#          0.835                    NaN         NaN         NaN      NaN
#          0.869                 0.0516      0.0168         NaN      NaN
# 720      0.747                    NaN         NaN      0.4223   0.1691
#          0.787                 0.2450      0.1382         NaN      NaN
#          0.849                    NaN         NaN      0.4154   0.1210
#          0.877                    NaN         NaN         NaN      NaN
#          0.892                    NaN         NaN         NaN      NaN
#          0.905                    NaN         NaN         NaN      NaN
#          0.972                 0.1610      0.0568         NaN      NaN
#          0.980                    NaN         NaN      0.3859   0.0755
#          1.035                 0.1320      0.0359         NaN      NaN
#
#                                                                        \
# type                      Constrained        ERM Constrained      ERM
# model                      Autoformer Autoformer    Reformer Reformer
# pred_len constraint_level
# 96       0.467                    NaN        NaN         NaN      NaN
#          0.475                    NaN        NaN         NaN      NaN
#          0.484                 0.0158     0.0194         NaN      NaN
#          0.527                    NaN        NaN      0.0027   0.0055
#          0.538                    NaN        NaN         NaN      NaN
#          0.548                    NaN        NaN         NaN      NaN
#          0.549                 0.0002     0.0029         NaN      NaN
#          0.565                    NaN        NaN      0.0006   0.0009
#          0.585                    NaN        NaN         NaN      NaN
# 192      0.525                    NaN        NaN         NaN      NaN
#          0.559                    NaN        NaN         NaN      NaN
#          0.563                    NaN        NaN         NaN      NaN
#          0.580                 0.0175     0.0329         NaN      NaN
#          0.598                    NaN        NaN      0.0014   0.0550
#          0.607                    NaN        NaN         NaN      NaN
#          0.627                    NaN        NaN      0.0010   0.0415
#          0.662                    NaN        NaN         NaN      NaN
#          0.667                    NaN        NaN      0.0010   0.0268
#          0.771                    NaN        NaN         NaN      NaN
# 336      0.577                    NaN        NaN         NaN      NaN
#          0.610                 0.0649     0.0411         NaN      NaN
#          0.622                    NaN        NaN         NaN      NaN
#          0.671                    NaN        NaN         NaN      NaN
#          0.679                 0.0134     0.0147         NaN      NaN
#          0.729                    NaN        NaN         NaN      NaN
#          0.730                    NaN        NaN      0.0048   0.1241
# ...
#          0.227                             NaN        NaN      0.4061
#          0.237                             NaN        NaN         NaN
#          0.238                             NaN        NaN         NaN
#          0.254                             NaN        NaN         NaN
#          0.257                             NaN        NaN         NaN
# 336      0.194                             NaN        NaN      0.5825
#          0.197                          0.4118        1.0         NaN
#          0.207                          0.3343        1.0         NaN
#          0.211                             NaN        NaN      0.5294
#          0.223                             NaN        NaN         NaN
#          0.234                             NaN        NaN      0.4234
#          0.236                             NaN        NaN         NaN
#          0.240                          0.1159        1.0         NaN
#          0.250                             NaN        NaN         NaN
#          0.254                             NaN        NaN         NaN
#          0.263                             NaN        NaN         NaN
#          0.296                             NaN        NaN         NaN
# 720      0.218                          0.6772        1.0         NaN
#          0.228                          0.4812        1.0         NaN
#          0.232                             NaN        NaN      0.5473
#          0.239                             NaN        NaN      0.5076
#          0.244                          0.4593        1.0         NaN
#          0.250                             NaN        NaN      0.4666
#          0.251                             NaN        NaN         NaN
#          0.254                             NaN        NaN         NaN
#          0.255                             NaN        NaN         NaN
#          0.309                             NaN        NaN         NaN
#          0.321                             NaN        NaN         NaN
#          0.352                             NaN        NaN         NaN
#
#                                                                         \
# type                              ERM Constrained      ERM Constrained
# model                     Transformer    Reformer Reformer    Informer
# pred_len constraint_level
# 96       0.151                    NaN         NaN      NaN         NaN
#          0.160                    NaN         NaN      NaN         NaN
#          0.166                    NaN         NaN      NaN         NaN
#          0.176                    1.0         NaN      NaN         NaN
#          0.181                    1.0         NaN      NaN         NaN
#          0.189                    1.0         NaN      NaN         NaN
#          0.198                    NaN      0.5018      1.0         NaN
#          0.202                    NaN      0.4705      1.0         NaN
#          0.207                    NaN      0.4497      1.0         NaN
#          0.224                    NaN         NaN      NaN      0.5061
#          0.226                    NaN         NaN      NaN      0.4790
#          0.232                    NaN         NaN      NaN      0.4598
# 192      0.174                    NaN         NaN      NaN         NaN
#          0.184                    NaN         NaN      NaN         NaN
#          0.197                    1.0         NaN      NaN         NaN
#          0.202                    NaN         NaN      NaN         NaN
#          0.211                    1.0         NaN      NaN         NaN
#          0.218                    NaN      0.5626      1.0         NaN
#          0.226                    NaN         NaN      NaN      0.5403
#          0.227                    1.0         NaN      NaN         NaN
#          0.237                    NaN         NaN      NaN      0.4878
#          0.238                    NaN      0.4931      1.0         NaN
#          0.254                    NaN      0.4485      1.0         NaN
#          0.257                    NaN         NaN      NaN      0.4170
# 336      0.194                    1.0         NaN      NaN         NaN
#          0.197                    NaN         NaN      NaN         NaN
#          0.207                    NaN         NaN      NaN         NaN
#          0.211                    1.0         NaN      NaN         NaN
#          0.223                    NaN      0.5500      1.0         NaN
#          0.234                    1.0         NaN      NaN         NaN
#          0.236                    NaN      0.4865      1.0         NaN
#          0.240                    NaN         NaN      NaN         NaN
#          0.250                    NaN         NaN      NaN      0.5266
#          0.254                    NaN      0.4195      1.0         NaN
#          0.263                    NaN         NaN      NaN      0.5017
#          0.296                    NaN         NaN      NaN      0.3997
# 720      0.218                    NaN         NaN      NaN         NaN
#          0.228                    NaN         NaN      NaN         NaN
#          0.232                    1.0         NaN      NaN         NaN
#          0.239                    1.0         NaN      NaN         NaN
#          0.244                    NaN         NaN      NaN         NaN
#          0.250                    1.0         NaN      NaN         NaN
#          0.251                    NaN      0.4872      1.0         NaN
#          0.254                    NaN      0.4712      1.0         NaN
#          0.255                    NaN      0.4680      1.0         NaN
#          0.309                    NaN         NaN      NaN      0.5185
#          0.321                    NaN         NaN      NaN      0.4830
#          0.352                    NaN         NaN      NaN      0.3703
#
#                                    std_infeasible_rate                         \
# type                           ERM         Constrained        ERM Constrained
# model                     Informer          Autoformer Autoformer Transformer
# pred_len constraint_level
# 96       0.151                 NaN                 NaN        NaN         NaN
#          0.160                 NaN                 NaN        NaN         NaN
#          0.166                 NaN                 NaN        NaN         NaN
#          0.176                 NaN                 NaN        NaN         NaN
#          0.181                 NaN                 NaN        NaN         NaN
#          0.189                 NaN                 NaN        NaN         NaN
#          0.198                 NaN                 NaN        NaN         NaN
#          0.202                 NaN                 NaN        NaN         NaN
#          0.207                 NaN                 NaN        NaN         NaN
#          0.224                 1.0                 NaN        NaN         NaN
#          0.226                 1.0                 NaN        NaN         NaN
#          0.232                 1.0                 NaN        NaN         NaN
# 192      0.174                 NaN                 NaN        NaN         NaN
#          0.184                 NaN                 NaN        NaN         NaN
#          0.197                 NaN                 NaN        NaN         NaN
#          0.202                 NaN                 NaN        NaN         NaN
#          0.211                 NaN                 NaN        NaN         NaN
#          0.218                 NaN                 NaN        NaN         NaN
#          0.226                 1.0                 NaN        NaN         NaN
#          0.227                 NaN                 NaN        NaN         NaN
#          0.237                 1.0                 NaN        NaN         NaN
#          0.238                 NaN                 NaN        NaN         NaN
#          0.254                 NaN                 NaN        NaN         NaN
#          0.257                 1.0                 NaN        NaN         NaN
# 336      0.194                 NaN                 NaN        NaN         NaN
#          0.197                 NaN                 NaN        NaN         NaN
#          0.207                 NaN                 NaN        NaN         NaN
#          0.211                 NaN                 NaN        NaN         NaN
#          0.223                 NaN                 NaN        NaN         NaN
#          0.234                 NaN                 NaN        NaN         NaN
#          0.236                 NaN                 NaN        NaN         NaN
#          0.240                 NaN                 NaN        NaN         NaN
#          0.250                 1.0                 NaN        NaN         NaN
#          0.254                 NaN                 NaN        NaN         NaN
#          0.263                 1.0                 NaN        NaN         NaN
#          0.296                 1.0                 NaN        NaN         NaN
# 720      0.218                 NaN                 NaN        NaN         NaN
#          0.228                 NaN                 NaN        NaN         NaN
#          0.232                 NaN                 NaN        NaN         NaN
#          0.239                 NaN                 NaN        NaN         NaN
#          0.244                 NaN                 NaN        NaN         NaN
#          0.250                 NaN                 NaN        NaN         NaN
#          0.251                 NaN                 NaN        NaN         NaN
#          0.254                 NaN                 NaN        NaN         NaN
#          0.255                 NaN                 NaN        NaN         NaN
#          0.309                 1.0                 NaN        NaN         NaN
#          0.321                 1.0                 NaN        NaN         NaN
#          0.352                 1.0                 NaN        NaN         NaN
#
#                                                                         \
# type                              ERM Constrained      ERM Constrained
# model                     Transformer    Reformer Reformer    Informer
# pred_len constraint_level
# 96       0.151                    NaN         NaN      NaN         NaN
#          0.160                    NaN         NaN      NaN         NaN
#          0.166                    NaN         NaN      NaN         NaN
#          0.176                    NaN         NaN      NaN         NaN
#          0.181                    NaN         NaN      NaN         NaN
#          0.189                    NaN         NaN      NaN         NaN
#          0.198                    NaN         NaN      NaN         NaN
#          0.202                    NaN         NaN      NaN         NaN
#          0.207                    NaN         NaN      NaN         NaN
#          0.224                    NaN         NaN      NaN         NaN
#          0.226                    NaN         NaN      NaN         NaN
#          0.232                    NaN         NaN      NaN         NaN
# 192      0.174                    NaN         NaN      NaN         NaN
#          0.184                    NaN         NaN      NaN         NaN
#          0.197                    NaN         NaN      NaN         NaN
#          0.202                    NaN         NaN      NaN         NaN
#          0.211                    NaN         NaN      NaN         NaN
#          0.218                    NaN         NaN      NaN         NaN
#          0.226                    NaN         NaN      NaN         NaN
#          0.227                    NaN         NaN      NaN         NaN
#          0.237                    NaN         NaN      NaN         NaN
#          0.238                    NaN         NaN      NaN         NaN
#          0.254                    NaN         NaN      NaN         NaN
#          0.257                    NaN         NaN      NaN         NaN
# 336      0.194                    NaN         NaN      NaN         NaN
#          0.197                    NaN         NaN      NaN         NaN
#          0.207                    NaN         NaN      NaN         NaN
#          0.211                    NaN         NaN      NaN         NaN
#          0.223                    NaN         NaN      NaN         NaN
#          0.234                    NaN         NaN      NaN         NaN
#          0.236                    NaN         NaN      NaN         NaN
#          0.240                    NaN         NaN      NaN         NaN
#          0.250                    NaN         NaN      NaN         NaN
#          0.254                    NaN         NaN      NaN         NaN
#          0.263                    NaN         NaN      NaN         NaN
#          0.296                    NaN         NaN      NaN         NaN
# 720      0.218                    NaN         NaN      NaN         NaN
#          0.228                    NaN         NaN      NaN         NaN
#          0.232                    NaN         NaN      NaN         NaN
#          0.239                    NaN         NaN      NaN         NaN
#          0.244                    NaN         NaN      NaN         NaN
#          0.250                    NaN         NaN      NaN         NaN
#          0.251                    NaN         NaN      NaN         NaN
#          0.254                    NaN         NaN      NaN         NaN
#          0.255                    NaN         NaN      NaN         NaN
#          0.309                    NaN         NaN      NaN         NaN
#          0.321                    NaN         NaN      NaN         NaN
#          0.352                    NaN         NaN      NaN         NaN
#
#
# type                           ERM
# model                     Informer
# pred_len constraint_level
# 96       0.151                 NaN
#          0.160                 NaN
#          0.166                 NaN
#          0.176                 NaN
#          0.181                 NaN
#          0.189                 NaN
#          0.198                 NaN
#          0.202                 NaN
#          0.207                 NaN
#          0.224                 NaN
#          0.226                 NaN
#          0.232                 NaN
# 192      0.174                 NaN
#          0.184                 NaN
#          0.197                 NaN
#          0.202                 NaN
#          0.211                 NaN
#          0.218                 NaN
#          0.226                 NaN
#          0.227                 NaN
#          0.237                 NaN
#          0.238                 NaN
#          0.254                 NaN
#          0.257                 NaN
# 336      0.194                 NaN
#          0.197                 NaN
#          0.207                 NaN
#          0.211                 NaN
#          0.223                 NaN
#          0.234                 NaN
#          0.236                 NaN
#          0.240                 NaN
#          0.250                 NaN
#          0.254                 NaN
#          0.263                 NaN
#          0.296                 NaN
# 720      0.218                 NaN
#          0.228                 NaN
#          0.232                 NaN
#          0.239                 NaN
#          0.244                 NaN
#          0.250                 NaN
#          0.251                 NaN
#          0.254                 NaN
#          0.255                 NaN
#          0.309                 NaN
#          0.321                 NaN
#          0.352                 NaN

# %% [markdown]
# ### Comparing variance and CoV ERM vs constrained

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 288 to 815
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Algorithm             240 non-null    object
#  1   model                 240 non-null    object
#  2   type                  240 non-null    object
#  3   constraint_level      240 non-null    float64
#  4   pred_len              240 non-null    int64
#  5   data_path             240 non-null    object
#  6   split                 240 non-null    object
#  7   mse                   240 non-null    float64
#  8   std_mse               0 non-null      float64
#  9   mcv                   240 non-null    float64
#  10  std_mcv               0 non-null      float64
#  11  mean_infeasible_rate  240 non-null    float64
#  12  std_infeasible_rate   0 non-null      float64
#  13  run_count             240 non-null    float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 28.1+ KB

# %%
df_to_plot.query("split=='test'").constraint_idx.unique()
# Out:
# array([3, 2, 1, 0])

# %%
# Calculate mean and std for mse and constraint_violation. Rename them mean_{metric} and std_{metric
#ToDO filter one seeed and split
stepwise_metrics = df_to_plot[df_to_plot.constraint_idx.isin([0,2])].query("split=='test'").groupby([
    "run_id",
    "Algorithm", #Harmless carryover col for legacy purposes (verified the counts are the same)
    "model",'type',
    "constraint_level",
    "constraint_idx",
    "pred_len",
    "data_path",
    "split",
    'step'#STEPWISE
    ])['mse','constraint_violation','infeasible_rate','run_id'].aggregate(
        mse=('mse','mean'),
        #std_mse=('mse','std'),
        mcv=('constraint_violation','mean'),
        #std_mcv=('constraint_violation','std'),
        mean_infeasible_rate=('infeasible_rate','mean'),
        #std_infeasible_rate=('infeasible_rate','std'),
        run_count=('run_id','nunique')
        ).reset_index().round(5)
summary_stepwise=stepwise_metrics.groupby([
    "run_id",
    "Algorithm", #Harmless carryover col for legacy purposes (verified the counts are the same)
    "model",
    'type',
    "constraint_level",
    "constraint_idx",
    "pred_len",
    "data_path",
    "split"]).aggregate(
        mse=('mse','mean'),
        std_mse=('mse','std'),
        mcv=('mcv','mean'),
        std_mcv=('mcv','std'),
        mean_infeasible_rate=('mean_infeasible_rate','mean'),
        std_infeasible_rate=('mean_infeasible_rate','std'),
        run_count=('run_count','mean'),
        step_count=('step','count')
    ).reset_index()
summary_stepwise
# Out:
# /home/jporras/miniconda3/envs/autoformer/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   del sys.path[0]
#        run_id                             Algorithm        model         type  \
# 0    02zvd69l             exchange_rate Transformer  Transformer  Constrained
# 1    07srnmcx              exchange_rate Autoformer   Autoformer  Constrained
# 2    092u33lj    AllModels_electricity.csv Reformer     Reformer          ERM
# 3    092u33lj    AllModels_electricity.csv Reformer     Reformer          ERM
# 4    092u33lj    AllModels_electricity.csv Reformer     Reformer          ERM
# ..        ...                                   ...          ...          ...
# 177  yhsan1ax        AllModels_weather.csv Informer     Informer          ERM
# 178  z46h4r20                electricity Autoformer   Autoformer  Constrained
# 179  zuqz5thy  AllModels_exchange_rate.csv Reformer     Reformer          ERM
# 180  zuqz5thy  AllModels_exchange_rate.csv Reformer     Reformer          ERM
# 181  zuqz5thy  AllModels_exchange_rate.csv Reformer     Reformer          ERM
#
#      constraint_level  constraint_idx  pred_len          data_path split  \
# 0               0.798               2       192  exchange_rate.csv  test
# 1               1.047               2       720  exchange_rate.csv  test
# 2               0.198               0        96    electricity.csv  test
# 3               0.202               0        96    electricity.csv  test
# 4               0.207               0        96    electricity.csv  test
# ..                ...             ...       ...                ...   ...
# 177             0.607               0       192        weather.csv  test
# 178             0.228               2       720    electricity.csv  test
# 179             1.137               0        96  exchange_rate.csv  test
# 180             1.221               0        96  exchange_rate.csv  test
# 181             1.495               0        96  exchange_rate.csv  test
#
#           mse   std_mse       mcv   std_mcv  mean_infeasible_rate  \
# 0    1.078070  0.283924  0.317347  0.222823               0.78976
# 1    0.982165  0.129014  0.024493  0.065788               0.32604
# 2    0.298882  0.010611  0.100882  0.010611               1.00000
# 3    0.298882  0.010611  0.096882  0.010611               1.00000
# 4    0.298882  0.010611  0.091882  0.010611               1.00000
# ..        ...       ...       ...       ...                   ...
# 177  0.514648  0.158067  0.034075  0.077200               1.00000
# 178  0.375928  0.253698  0.147928  0.253698               0.95283
# 179  0.960433  0.115636  0.001075  0.005120               1.00000
# 180  0.960433  0.115636  0.000000  0.000000               1.00000
# 181  0.960433  0.115636  0.000000  0.000000               1.00000
#
#      std_infeasible_rate  run_count  step_count
# 0                    0.0        1.0         192
# 1                    0.0        1.0         720
# 2                    0.0        1.0          96
# 3                    0.0        1.0          96
# 4                    0.0        1.0          96
# ..                   ...        ...         ...
# 177                  0.0        1.0         192
# 178                  0.0        1.0         720
# 179                  0.0        1.0          96
# 180                  0.0        1.0          96
# 181                  0.0        1.0          96
#
# [182 rows x 17 columns]

# %%
summary_stepwise.groupby(['run_id','type','constraint_idx',"Algorithm","model"]).size().reset_index()
# Out:
#       run_id         type  constraint_idx  \
# 0   02zvd69l  Constrained               2
# 1   07srnmcx  Constrained               2
# 2   092u33lj          ERM               0
# 3   0roswz2a          ERM               0
# 4   0uvkl0hn  Constrained               2
# ..       ...          ...             ...
# 88  xyee0xef  Constrained               2
# 89  y7ygu53t  Constrained               2
# 90  yhsan1ax          ERM               0
# 91  z46h4r20  Constrained               2
# 92  zuqz5thy          ERM               0
#
#                                Algorithm        model  0
# 0              exchange_rate Transformer  Transformer  1
# 1               exchange_rate Autoformer   Autoformer  1
# 2     AllModels_electricity.csv Reformer     Reformer  3
# 3   AllModels_electricity.csv Autoformer   Autoformer  3
# 4                 exchange_rate Reformer     Reformer  1
# ..                                   ...          ... ..
# 88                      weather Informer     Informer  1
# 89              exchange_rate Autoformer   Autoformer  1
# 90        AllModels_weather.csv Informer     Informer  3
# 91                electricity Autoformer   Autoformer  1
# 92  AllModels_exchange_rate.csv Reformer     Reformer  3
#
# [93 rows x 6 columns]

# %%
dd_weather = summary_stepwise.query('data_path=="weather.csv" and pred_len==96').copy()
dd_weather.groupby(['run_id','constraint_idx',"Algorithm","model","constraint_idx"])
#dd_weather.pivot(index=['run_id','constraint_idx',"Algorithm","model","constraint_idx"], columns='type', values='mse')

# %% [markdown]
# #### Pivot tables stepwise

# %%
#Note, variance is nan because there is only one run per parameter set
weather = summary_stepwise.query('data_path=="weather.csv"').copy()
electricity = summary_stepwise.query('data_path=="electricity.csv"').copy()
for name,dataset in [('weather',weather), ('electricity',electricity)]:
    display(Markdown(f"# {name}"))
    tp2=dataset.copy(deep=True)
    #tp2=weather.query('split=="test"').copy()
    # Compute 'infeasible amount' as the difference between the mse and the constraint_level, 0 if mse < constraint
    #tp2['mean_violation']=tp2.apply(lambda x: max(0,x['mse']-x['constraint_level']),axis=1)
    
    # Split into constrained and ERM
    tp2_constrained=tp2.query('type=="Constrained"').copy()
    tp2_erm_baseline=tp2.query('type=="ERM"').copy()

    distinct_constraints = tp2_constrained[['pred_len','model','constraint_level']].drop_duplicates()

    # crossjoin the ERM mse to all constraint levels
    #tp2_erm_baseline_broadcasted = tp2_erm_baseline.drop(columns=['constraint_level']).merge(distinct_constraints,on=['pred_len','model'],how='left')

    #display(tp2_erm_baseline_broadcasted[['type','model','constraint_level','mse']].head())

    # concat back together to compute mean_violation
    #tp2=pd.concat([tp2_constrained,tp2_erm_baseline_broadcasted],axis=0)

    #tp2['mean_violation']=tp2.apply(lambda x: max(0,x['mse']-x['constraint_level']),axis=1)

    # Sanity check show the mean_violation for the ERM runs
    #display(tp2.query('type=="ERM"')[['type','model','constraint_level','mse','mean_violation']].head())


    #GROUPING TEH VALS
    grouped_values=tp2.groupby(['pred_len','constraint_level','constraint_idx','model','type'])[[
        'mse','mcv',
        'std_mse','std_mcv',
        'mean_infeasible_rate','std_infeasible_rate']].mean().reset_index()
    #grouped_constrained = grouped_values[grouped_values.type=='Constrained'].copy()
    #grouped_erm_baseline=grouped_values[grouped_values.type=='ERM'].copy()

    # best_constraints is the constraint for each model and pred_len that minimizes mean_violation. show min and argmin
    #best_constraints_per_window = grouped_values.query('type=="Constrained"').groupby(['pred_len']).apply(lambda x: x.loc[x['mean_violation'].idxmin()]).reset_index(drop=True)[['pred_len','type','constraint_level','mean_violation','mse']]
    # instead of best constraints, show all constraint levels.

    # join best_constraints and grouped_values to get the mse and mean_violation for the best constraint
    #best_constrained=grouped_values.merge(best_constraints_per_window[['pred_len','constraint_level']],on=['pred_len','constraint_level'],how='inner')


    # crossjoin the ERM mse to all constraint levels
    ##grouped_erm_baseline_broadcasted = grouped_erm_baseline.drop(columns=['constraint_level']).merge(grouped_constrained[['pred_len','model','constraint_level']].drop_duplicates(),on=['pred_len','model'],how='left')

    # Pivot of models versus constrained and ERM, values are mse and mse_diff
    all_results = grouped_values#pd.concat([grouped_constrained,grouped_erm_baseline_broadcasted],axis=0)
    # Pivot all results, sort ascending by pred_len, then mean_violation on constrained

    pivoted=all_results.pivot(
        index=['pred_len','constraint_idx'], 
        columns=['type','model'],
        values=['mse','std_mse','mcv','std_mcv','mean_infeasible_rate','std_infeasible_rate']
    ).query('constraint_level>0').round(4)
    simplified = all_results.pivot(
        index=['pred_len','constraint_level'],
        columns=['type','model'],
        values=['mse','mcv']
    )
    pd.set_option('display.max_columns', None)
    print("SIMPLIFIED 192 MSE")
    # show all pred lengths (index)
    for pred_len in [96, 192, 336, 720]:    
        print(simplified.index.get_level_values(0).unique())
        simp_mse_192=simplified[simplified.index.get_level_values(0)==pred_len][['mse']]
        sim_mcv_192=simplified[simplified.index.get_level_values(0)==pred_len][['mcv']]

        # Flatten the multiindex
        def prettify(d):
            d = d.copy()
            d.columns = d.columns.map('_'.join)
            return d.style.format(precision=3)
        # display(prettify(simp_mse_192))
        print(f"SIMPLIFIED {pred_len} MCV")
        display(prettify(sim_mcv_192))
    print("FULL")
    display(pivoted)
    #reformer works best on weather.
# Out:
# # weather
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3957507/1633369330.py in <module>
#      55         index=['pred_len'],
#      56         columns=['type','model'],
# ---> 57         values=['mse','std_mse','mcv','std_mcv','mean_infeasible_rate','std_infeasible_rate']
#      58     ).query('constraint_level>0').round(4)
#      59     simplified = all_results.pivot(
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    8322         from pandas.core.reshape.reshape import unstack
#    8323
# -> 8324         result = unstack(self, level, fill_value)
#    8325
#    8326         return result.__finalize__(self, method="unstack")
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     435             # _unstack_multiple only handles MultiIndexes,
#     436             # and isn't needed for a single level
# --> 437             return _unstack_multiple(obj, level, fill_value=fill_value)
#     438         else:
#     439             level = level[0]
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _unstack_multiple(data, clocs, fill_value)
#     404         dummy.index = dummy_index
#     405
# --> 406         unstacked = dummy.unstack("__placeholder__", fill_value=fill_value)
#     407         if isinstance(unstacked, Series):
#     408             unstcols = unstacked.index
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    8322         from pandas.core.reshape.reshape import unstack
#    8323
# -> 8324         result = unstack(self, level, fill_value)
#    8325
#    8326         return result.__finalize__(self, method="unstack")
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     445     if isinstance(obj, DataFrame):
#     446         if isinstance(obj.index, MultiIndex):
# --> 447             return _unstack_frame(obj, level, fill_value=fill_value)
#     448         else:
#     449             return obj.T.stack(dropna=False)
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _unstack_frame(obj, level, fill_value)
#     472         return obj._constructor(mgr)
#     473     else:
# --> 474         unstacker = _Unstacker(obj.index, level=level, constructor=obj._constructor)
#     475         return unstacker.get_result(
#     476             obj._values, value_columns=obj.columns, fill_value=fill_value
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     131             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     132
# --> 133         self._make_selectors()
#     134
#     135     @cache_readonly
#
# ~/miniconda3/envs/autoformer/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     183
#     184         if mask.sum() < len(self.index):
# --> 185             raise ValueError("Index contains duplicate entries, cannot reshape")
#     186
#     187         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# ## Pivots per dataset
